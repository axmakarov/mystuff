# %%
import json
import requests
import pandas as pd
from datetime import timedelta, date

def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

url = 'http://192.168.10.5:4000/api/OLAP/Plain'
headers = {'Content-Type': 'application/json'} 

start_date = date(2015, 12, 1)
end_date = date(2015, 12, 2)
date1 = start_date
i = 0
for single_date in daterange(start_date + timedelta(1), end_date + timedelta(1)):
    print 'Start_date', date1,
    date2 = single_date.strftime("%Y-%m-%d")
    print 'End_date', date2
    print 'Make request'
    data = {
    "sources": ["direct_conversion"],
    "metrics": [
        "visits",
            "shows",
            "clicks",
            "avgClickPosition",
            "spent",
    "cpaVisits"],
    "segments": [{
        "dateStart": "{0}T00:00:00+03:00".format(date1),
        "dateEnd": "{0}T00:00:00+03:00".format(date2),
        "filters": {
            "campaignTypeId": {
                "type":"DIMENSION",
                "ids":["1","2"]
            }
        }
        }
    ],
    "dimensions": {
            "dateDay": 1,
        "campaignExternalId": 2,
            "adExternalId": 3
    }
}
    jdata = json.dumps(data)
    date1 = date2
    response = requests.post(url,jdata,headers=headers)
    with open('D:\\olap\\{0}.json'.format(i),'wb') as f1:
        print >>f1, response.text
    i += 1
# Out:
# Start_date 2015-12-01 End_date 2015-12-02
# Make request

# %%
allData = []
for item in responseData:
    allData += json.loads(item)

# %%
g = []
for k,v in data['dimensions'].iteritems():
    g.append({'key': k, 'value': v})

# %%
g
# Out:
# [{'key': 'keyPhraseName', 'value': 3},
#  {'key': 'dateDay', 'value': 1},
#  {'key': 'campaignExternalId', 'value': 2}]

# %%
from operator import itemgetter
sortedG = sorted(g, key=itemgetter('value'))

# %%
sortedG
# Out:
# [{'key': 'dateDay', 'value': 1},
#  {'key': 'campaignExternalId', 'value': 2},
#  {'key': 'keyPhraseName', 'value': 3}]

# %%
editedData = []
for item in allData:
    i = 0
    d = {}
    for dimensionValue in item['dimensions']:
        dimensionName = sortedG[i]['key']
        d[dimensionName] = dimensionValue
        i += 1
    metrics = item['value'][0]
    for k,v in metrics.iteritems():
        d[k] = v
    editedData.append(d)

# %%
pd.DataFrame(editedData).to_excel('d:\\cpa_kavichki.xlsx')

# %%
len(allData)
# Out:
# 70452

# %%
import json
import requests
import pandas as pd
from datetime import timedelta, date

# %%
url = 'http://192.168.10.5:4000/api/OLAP/Plain'
headers = {'Content-Type': 'application/json'}

# %%
campaignIds = [u'14388896',
 u'15277992',
 u'15220939',
 u'15220937',
 u'15255492',
 u'13007173',
 u'16117607',
 u'13115780',
 u'14718426',
 u'14208120',
 u'15754324',
 u'15220987',
 u'15220986',
 u'15808246',
 u'15220989',
 u'11894512',
 u'16054170',
 u'14599049',
 u'15277561',
 u'14216950',
 u'14216952',
 u'16141730',
 u'13577092',
 u'16280785',
 u'15070787',
 u'12835092',
 u'16093132',
 u'14811254',
 u'14916983',
 u'15616879',
 u'15733858',
 u'14388886',
 u'14465228',
 u'15555848',
 u'15524771',
 u'13519402',
 u'15221123',
 u'15793039',
 u'15221121',
 u'15221126',
 u'10784315',
 u'16317197',
 u'15221129',
 u'16368789',
 u'15982179',
 u'15046688',
 u'13080872',
 u'15054336',
 u'15888800',
 u'14718765',
 u'16204767',
 u'16040960',
 u'15989618',
 u'14207184',
 u'13117209',
 u'13378136',
 u'15221138',
 u'12993244',
 u'16041002',
 u'14268267',
 u'15982995',
 u'15967307',
 u'14959258',
 u'12372191',
 u'15932422',
 u'11626739',
 u'16095446',
 u'13348281',
 u'16087320',
 u'16082791',
 u'14321934',
 u'15374516',
 u'14321932',
 u'15101922',
 u'16323100',
 u'11626125',
 u'16436018',
 u'15868173',
 u'15904805',
 u'13740782',
 u'16372416',
 u'15098335',
 u'13020422',
 u'12387720',
 u'15386945',
 u'15282325',
 u'15457896',
 u'14209348',
 u'14209345',
 u'16041076',
 u'15823936',
 u'14209358',
 u'15273401',
 u'16093119',
 u'14740340',
 u'15221083',
 u'14959206',
 u'14959202',
 u'14959209',
 u'16235643',
 u'15822127',
 u'16235646',
 u'14279893',
 u'14256349',
 u'10625756',
 u'15603576',
 u'15737090',
 u'15138209',
 u'14996990',
 u'14465165',
 u'16117538',
 u'13868483']

# %%
cnt = len(campaignIds)
i = 1
for campaignId in campaignIds:
    print '{0} of {1}: {2}'.format(i,cnt,campaignId)
    data = {
    "sources": ["direct_conversion"],
    "metrics": [
        "shows",
        "clicks",
        "cpaVisits",
        "visits",
        "avgClickPosition",
        "sumAvgClickPosition",
        "spent"],
    "segments": [{
        "dateStart": "2016-01-01T00:00:00+03:00",
        "dateEnd": "2016-01-28T00:00:00+03:00",
        "filters": {
            "campaignTypeId": {
                "type":"DIMENSION",
                "ids":["1","2"]
            },
            "campaignExternalId": {
                "type": "DIMENSION",
                "ids":["{0}".format(campaignId)]
            }
            }
        }
    ],
    "dimensions": {
        "dateDay": 1,
        "campaignExternalId": 2,
        "adExternalId": 3
    }
}
    jdata = json.dumps(data)
    response = requests.post(url,jdata,headers=headers)
    with open('D:\\olap\\{0}.json'.format(campaignId),'wb') as f1:
        print >>f1, response.text
    i += 1
# Out:
# 1 of 531: 14388896
# 2 of 531: 15277992
# 3 of 531: 15220939
# 4 of 531: 15220937
# 5 of 531: 15255492
# 6 of 531: 13007173
# 7 of 531: 16117607
# 8 of 531: 13115780
# 9 of 531: 14718426
# 10 of 531: 14208120
# 11 of 531: 15754324
# 12 of 531: 15220987
# 13 of 531: 15220986
# 14 of 531: 15808246
# 15 of 531: 15220989
# 16 of 531: 11894512
# 17 of 531: 16054170
# 18 of 531: 14599049
# 19 of 531: 15277561
# 20 of 531: 14216950
# 21 of 531: 14216952
# 22 of 531: 16141730
# 23 of 531: 13577092
# 24 of 531: 16280785
# 25 of 531: 15070787
# 26 of 531: 12835092
# 27 of 531: 16093132
# 28 of 531: 14811254
# 29 of 531: 14916983
# 30 of 531: 15616879
# 31 of 531: 15733858
# 32 of 531: 14388886
# 33 of 531: 14465228
# 34 of 531: 15555848
# 35 of 531: 15524771
# 36 of 531: 13519402
# 37 of 531: 15221123
# 38 of 531: 15793039
# 39 of 531: 15221121
# 40 of 531: 15221126
# 41 of 531: 10784315
# 42 of 531: 16317197
# 43 of 531: 15221129
# 44 of 531: 16368789
# 45 of 531: 15982179
# ...

# %%
from os import listdir
from os.path import isfile, join
from operator import itemgetter
import json

campaignId = '0'
data = {
    "sources": ["direct_conversion"],
    "metrics": [
        "shows",
        "clicks",
        "cpaVisits",
        "visits",
        "avgClickPosition",
        "sumAvgClickPosition",
        "spent"],
    "segments": [{
        "dateStart": "2016-01-01T00:00:00+03:00",
        "dateEnd": "2016-01-28T00:00:00+03:00",
        "filters": {
            "campaignTypeId": {
                "type":"DIMENSION",
                "ids":["1","2"]
            },
            "campaignExternalId": {
                "type": "DIMENSION",
                "ids":["{0}".format(campaignId)]
            }
            }
        }
    ],
    "dimensions": {
        "dateDay": 1,
        "campaignExternalId": 2,
        "adExternalId": 3
    }
}

g = []
for k,v in data['dimensions'].iteritems():
    g.append({'key': k, 'value': v})
sortedG = sorted(g, key=itemgetter('value'))

mypath = 'D:\\olap\\'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
olapData = []
for f in onlyfiles:
    filepath = mypath + f
    print filepath
    with open(filepath,'r+') as f1:
        smallData = json.load(f1)
        d = {}
        for item in smallData:
            i = 0
            for dimensionValue in item['dimensions']:
                dimensionName = sortedG[i]['key']
                d[dimensionName] = dimensionValue
                i += 1
            metrics = item['value'][0]
            for k,v in metrics.iteritems():
                d[k] = v
            olapData.append(d)
# Out:
# D:\olap\10489147.json
# D:\olap\10625756.json
# D:\olap\10717548.json
# D:\olap\10730032.json
# D:\olap\10781855.json
# D:\olap\10784315.json
# D:\olap\10804265.json
# D:\olap\10942083.json
# D:\olap\10966289.json
# D:\olap\11445185.json
# D:\olap\11454742.json
# D:\olap\11502538.json
# D:\olap\11584389.json
# D:\olap\11626125.json
# D:\olap\11626739.json
# D:\olap\11626791.json
# D:\olap\11677271.json
# D:\olap\11677561.json
# D:\olap\11894512.json
# D:\olap\12219321.json
# D:\olap\12372191.json
# D:\olap\12387720.json
# D:\olap\12479440.json
# D:\olap\12495018.json
# D:\olap\12698091.json
# D:\olap\12820672.json
# D:\olap\12835092.json
# D:\olap\12882571.json
# D:\olap\12912472.json
# D:\olap\12917204.json
# D:\olap\12917902.json
# D:\olap\12968106.json
# D:\olap\12968707.json
# D:\olap\12993244.json
# D:\olap\12993449.json
# D:\olap\12999846.json
# D:\olap\13007173.json
# D:\olap\13012253.json
# D:\olap\13020422.json
# D:\olap\13028870.json
# D:\olap\13029536.json
# ...

# %%
len(olapData)
# Out:
# 46153

# %%
g = []
for k,v in data['dimensions'].iteritems():
    g.append({'key': k, 'value': v})

# %%
from operator import itemgetter
sortedG = sorted(g, key=itemgetter('value'))

# %%
sortedG
# Out:
# [{'key': 'dateDay', 'value': 1},
#  {'key': 'campaignExternalId', 'value': 2},
#  {'key': 'adExternalId', 'value': 3}]

# %%
editedData = []
for item in olapData:
    i = 0
    d = {}
    for dimensionValue in item['dimensions']:
        dimensionName = sortedG[i]['key']
        d[dimensionName] = dimensionValue
        i += 1
    metrics = item['value'][0]
    for k,v in metrics.iteritems():
        d[k] = v
    editedData.append(d)

# %%
len(editedData)
# Out:
# 1824780

# %%
import pandas as pd
pd.DataFrame(olapData)
# Out:
#       adExternalId  avgClickPosition campaignExternalId  clicks  cpaVisits  \
# 0        859690427                 0           10489147       0          0
# 1        859690427                 0           10489147       0          0
# 2        859690427                 0           10489147       0          0
# 3        859690427                 0           10489147       0          0
# 4        859690427                 0           10489147       0          0
# 5        859690427                 0           10489147       0          0
# 6        859690427                 0           10489147       0          0
# 7        859690427                 0           10489147       0          0
# 8        859690427                 0           10489147       0          0
# 9        859690427                 0           10489147       0          0
# 10       859690427                 0           10489147       0          0
# ...

# %%
with open('D:\\olap\\allData.json','wb') as f2:
    print >>f2, json.dumps(editedData)

# %%
sortedG
# Out:
# [{'key': 'dateDay', 'value': 1},
#  {'key': 'campaignExternalId', 'value': 2},
#  {'key': 'adExternalId', 'value': 3}]
