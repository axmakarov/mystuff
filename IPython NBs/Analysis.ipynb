# %% [markdown]
# # Анализ объявлений и построение прогнозной модели посещаемости

# %% [markdown]
# Для выполнения проекта была поставлена задача построить модель, которая могла бы по тексту объявления в интернете спрогнозировать посещаемость данного объявления. Для получения данных был разработан краулер, который скачивал объявления с сайта и формировал итоговый csv-файл. Тематика объявлений была одинакова для всех - передача собак из приютов и от частных лиц в добрые руки.

# %% [markdown]
# ## Загрузка библиотек

# %%
# %matplotlib inline

import datetime

import warnings
warnings.filterwarnings('ignore')

import seaborn

# кириллица на графиках
from matplotlib import rc
font = {'family': 'Verdana',
        'weight': 'normal'}
rc('font', **font)

import matplotlib.pyplot as plt



from pylab import rcParams
rcParams['figure.figsize'] = 15, 10

import pandas as pd
pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.expand_frame_repr', True)

import numpy as np

from sklearn.feature_extraction.text import CountVectorizer,TfidfTransformer

from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.cross_validation import cross_val_score, train_test_split
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import SGDClassifier
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from sklearn.learning_curve import validation_curve,learning_curve

from sklearn.base import TransformerMixin

from sklearn.feature_selection import SelectKBest, chi2



from nltk.corpus import stopwords
from nltk.stem.snowball import RussianStemmer
import Stemmer
# Out:
# height has been deprecated.

# %% [markdown]
# ## Описание данных

# %% [markdown]
# В исходных данных содержится название, описание и общее число посещений объявления с начала публикации.

# %% [markdown]
# ### Список переменных

# %% [markdown]
# 1. description - полный текст объявления
# + identificator - номер объявления на сайте
# + num_counts - число посещений объявления с начала его размещения
# + price - цена, за которую предлагается купить животное. обычно, волонтеры ставят 100р. или вовсе не указывают цену.
# + start_date - дата, когда объявление было размещено
# + title - название объявления, как оно выглядит на первой странице.

# %%
dataset = pd.read_csv('dataset.csv', header = 0)

# %%
dataset.head()
# Out:
#                                          description  identificator  num_counts      price        start_date                                              title
# 0  Маечка небольшая ласковая девочка. Красивая и ...      101330173        2066  Неуказана  24 сентября 2012  Удивительный метис лайки Маечка ищет семью (в ...
# 1  Зося – милая, совсем простая собака. Не может ...      101766363         810  Неуказана  26 сентября 2012  Зося-просто скромная собака, верная подруга. В...
# 2  Реми застенчивая девчушка, никак не может прив...      104275455         928  Неуказана    7 октября 2012      Скромная застенчивая Реми в добрые руки в дар
# 3  кане корсо для вязки Дата рождения 04.03.2008 ...       10636944        4358  Неуказана   6 сентября 2010                          Кане Корсо, Кобель, вязка
# 4  Жизнерадостная, энергичная, очень самоуверенна...      106432433        1567  Неуказана   16 октября 2012     Обаятельнейшая, энергичная, самоуверенная Рада

# %%
dataset.shape
# Out:
# (3879, 6)

# %% [markdown]
# ### Описательные статистики

# %%
# посещаемость
dataset['num_counts'].hist(bins = 20)
plt.title('Number of views')
plt.show()

# логарифм посещаемости
dataset['num_counts'].apply(np.log).hist()
plt.title('Log of Number of views')
plt.show()

# %%
# цена
print(pd.value_counts(dataset['price']).head(20))
# Out:
# Неуказана     2566
# 100            486
# Договорная     115
# 50              73
# 500             67
# 30000           48
# 50000           47
# 40000           41
# 60000           40
# 35000           36
# 25000           35
# 20000           30
# 1000            27
# 15000           24
# 10000           23
# 300             19
# 200             19
# 45000           19
# 5000            11
# 65000           10
# Name: price, dtype: int64

# %% [markdown]
# Число слов в объявлении:

# %%
num_of_words = dataset['description'].apply(lambda x: len(x.split(' ')))
plt.hist(num_of_words)
plt.title('Distribution of the number of words')

# %% [markdown]
# Диаграммы рассеяния будут построены после предобработки

# %% [markdown]
# ## Предобработка
#
# 1. Признаками будут являться отдельные слова или биграммы, поэтому их необходимо нормализовать, чтобы одно и то же слово, но в разных формах не считалось как два разных. Эта операция называется стемминг, что согласно вики значит процесс нахождения основы слова для заданного исходного слова.
# 2. Поле "date" содержит дату в форме строки, поэтому ее нужно перевести в правильный формат
# 3. В качестве признака берется поле "description", поэтому текст необходимо перевести в представление "bag of words" и применить tf-idf. При этом из текста убираются предлоги, вспомогательные частицы и т.д. Эти слова называются stopwords.
# 4. Поскольку каждое объявление имеет свою дату публикации, то целевая переменная здесь представляет не просто число просмотров, а число просмотров, разделенное на число дней с момента подачи до скачивания их моим краулером. Т.е. можно считать, что это грубая оценка числа посетителей в сутки.
# 5. После нескольких неудачных попыток восстановить регрессию между document-term matrix и средним числом посетителей, было принято решение разбить целевую переменную на интервалы(квартили) и рассматривать задачу классификации (отсюда и tf-idf). Т.е. на выходе модель будет прогнозировать интервал, где содержится средняя посещаемость для данного объявления. Преобразование в квартили производилось только на обучающей выборке, поэтоу необходимо написать функцию, которая преобразовает и тестовую. Преобразовывать всю выборку целиком нельзя, посольку тогда тестовые данные будут косвенно участвовать в обучении.
# 6. Поле 'price' представляет собой цену за животное. Большие цены являются индикатором продажи породистого животного, нас же интересует некоммерческая деятельность, поэтому оставляем только те записи, для которых price < 500р.
# 7. Разбиение на train\test. Причем на train будет проводится обучение и подбор параметров по сетке на кросс-валидации, а на test будет проверяться финальное качество. Основная метрика - accuracy

# %%
# стемминг
stop = stopwords.words('russian')
stemobject = Stemmer.Stemmer('russian')#RussianStemmer()
def stemmer(x):
    stem_function = stemobject.stemWord
    out = [stem_function(word) for word in x.split(' ')]
    return ' '.join(out)

# преобразование тестовых данных в квартили
def y_transform(x):
    
    if isinstance(x,str):
        return x
    
    categories = y_train.unique().categories.get_values()
    
    first = categories[0]
    first = first.replace('[','').replace(']','').split(',')
    first = [float(i) for i in first]

    last = categories[-1]
    last = last.replace('(','').replace(']','').split(',')
    last = [float(i) for i in last]
    
    if (x < first[0]):
        return categories[0] 
        
    if (x >= first[0]) & (x <= first[1]):
        return categories[0]
    
    if (x >= last[0]) & (x <= last[1]):
        return categories[-1] 
    
    if (x >= last[1]):
        return categories[-1]  
        
    for cat in categories[1:-1]:
        c = cat.replace('(','').replace(']','').split(',')
        c = [float(i) for i in c]
        if (x > c[0]) & (x <= c[1]):
            return cat
        
# обработка даты
month = ['января','февраля','марта','апреля','мая','июня','июля','августа','сентября','октября','ноября','декабря']
order = {M: i+1 for i,M in enumerate(month)}

def date_helper(x):
    now = datetime.datetime(2016,3,18)
    x = x.split(' ')
    d = x[0]
    m = order[x[1]]
    y = x[2]
    
    dateobject =  datetime.datetime(int(y),int(m),int(d))
    delta = now-dateobject
    return delta.days

# %%
# идентификатор не несет полезной нагрузки
dataset.drop(['identificator'], axis = 1, inplace = True)

# %%
dataset['num_days'] = dataset['start_date'].apply(date_helper)
dataset.drop(['start_date'], axis = 1, inplace = True)

# %% [markdown]
# Создание новой целевой переменной как отношения общего числа посещений к числу дней, прошедших с момента публикации до момента попадания объявления в выборку. В знаменателе добавляет единичка, чтобы избежать деления на нуль.

# %%
dataset['mean_count'] = dataset['num_counts'] / (dataset['num_days']+1)
dataset.drop(['num_counts'], axis = 1, inplace = True)
dataset.drop(['num_days'], axis = 1, inplace = True)

# %%
dataset.describe()
# Out:
#         mean_count
# count  3879.000000
# mean     12.932416
# std      27.590200
# min       0.088768
# 25%       1.639117
# 50%       4.491228
# 75%      12.714286
# max     613.000000

# %% [markdown]
# Ниже на графике видно, что чем меньше слов в объявлении, тем больше просмотров, если оценивать грубо. Предполагаю, что это справедливо только для объявлений данной конкретной тематики, поскольку чем больше слов, тем скорее всего сложнее история у животного.

# %%
plt.scatter(num_of_words,dataset['mean_count'])
plt.xlabel('Number of words')
plt.ylabel('Number of visits')

# %% [markdown]
# Рассмотрим те объявления, которые составляют топ-20 по среднему числу посещений:

# %%
sorted_df = dataset.sort(['mean_count'], ascending=False)
for i in (sorted_df.index.tolist()[:10]):
    print('==================')
    print('\nНазвание: ')
    print('----------')
    print(sorted_df.loc[i,'title'])
    
    print('\nОписание: ')
    print('----------')
    print(sorted_df.loc[i,'description'])

    
    print('\nСреднее число просмотров: ',sorted_df.loc[i,'mean_count'])
    print('--------------------------')
# Out:
# ==================
#
# Название:
# ----------
# Щенки ищут заботливых хозяев
#
# Описание:
# ----------
# Подарите себе радость – приобретите верного друга! За символическую плату отдадим в хорошие добрые руки щенка породистых собак с отличными родословными. Папа- неоднократный призер выставок, бернский зенненхунд, красавец и умница. Мама – черный русский терьер, прекрасная охранница, послушное, ласковое и верное существо! Щенки родились 16 января 2016 г. Уже умеют самостоятельно есть, исполняют некоторые команды ( например команду «ко мне»).  Пока есть  и девочки и мальчики. Щенки очень забавные, подвижные, веселые, с прекрасным аппетитом. Привиты.
#
# Среднее число просмотров:  613.0
# --------------------------
# ==================
#
# Название:
# ----------
# Щенок вельш корги пемброк
#
# Описание:
# ----------
# Продается очаровательный мальчик вельш корги пемброк, рыжий, натуральный бобтейл от чистокровных родителей. У щенка неправильный прикус, вследствие чего он не может выставляться на выставках и участвовать в племенном разведении. Ищет заботливую семью, желательно с детьми. Прививки и документы по возрасту. Подробности по телефону.
#
# Среднее число просмотров:  583.0
# --------------------------
# ==================
#
# Название:
# ----------
# Отдам щенка в добрые руки
#
# Описание:
# ----------
# Москва и МО! Отдается в ответственные руки по договору ответственного содержания щенок близкий метис бельгийской овчарки, здоров, проглистогонен, полностью привит.
#
# Среднее число просмотров:  324.0
# --------------------------
# ==================
#
# Название:
# ----------
# Вельш корги пемброк резервирование РКФ
#
# Описание:
# ----------
# предлагаются к резервированию перспективные щенки вельшкорги пемброк внуки мультичемпиона чемпиона мира Андвол Я Твой Кумир отец ЮЧРоссии ЧРоссии питомник  Лайф Спринг чемпионы США дата рождения 10 марта красивые окрасы с хвостиками и купироваными хвостиками девочки и мальчики прекрасный выбор красивые окрасы цены договорные зарезервированым щенкам скидка родословная РКФ профессионально выращиваются все вопросы по телефону возможна доставка в регионы
#
# Среднее число просмотров:  296.0
# --------------------------
# ==================
#
# Название:
# ----------
# Отдадим в очень хорошие руки
#
# Описание:
# ----------
# Очень хороший,добрый кабель, детей не трогал никогда, играет с ними. Живем в квартире, дома не гадит. Проблема вся в том что муж работает большими вахтами , а я с двумя очень маленькими детьми и собака , не справляюсь. Пёсику приблизительно 7 месяцев, помесь Лабрадора с кем точно не знаем нам его подарили.
#
# Среднее число просмотров:  290.0
# --------------------------
# ==================
#
# Название:
# ----------
# Щенок вельш корги пемброк
#
# Описание:
# ----------
# Предлагаем трехцветную девочку вельш корги пемброк. Щенок с хвостиком. Дата рождения 7 января. Документы РКФ. Прививки по возрасту. Можно будет гулять с 14 апреля. Здоровая и активная девочка. Золотой характер. Подойдет для выставок и разведения. Щенок находится в г. Воронеж. Поможем с доставкой.
#
# Среднее число просмотров:  236.0
# --------------------------
# ==================
#
# Название:
# ----------
# Русская гончая в дар
#
# Описание:
# ----------
# Русская гончая.  Гордей. Парень супер! Компаньон. Любит всех, в том числе и добычу))) так что охотник никакой))). Строго в дом. Не в вольер!! Чем больше семья тем лучше )))) Отдаем ответственным людям. Звоните!
#
# Среднее число просмотров:  229.0
# --------------------------
# ==================
#
# Название:
# ----------
# Девочка от вельш корги
#
# Описание:
# ----------
# Осталась одна девочка(беленькая). Мама корги,папа чихуахуа. Будет небольшая. Имеется вет.паспорт. Доставка по договоренности.
#
# Среднее число просмотров:  209.5
# --------------------------
# ==================
#
# Название:
# ----------
# Вельш Корги Пемброк (Флаффи)
#
# Описание:
# ----------
# Предлагаем двух девочек вельш корги пемброк. Не для выставок, не для разведения. Щенки флаффи ( длинношерстные). Возраст 1,5 мес. Документы РКФ. Щенки отлично социализированы, знакомы с кошкой, растут в доме с ребенком. Отличная собака в семью. Помощь в выращивание и воспитание. Возможна доставка На фото щенки которые продаются, и взрослая собака с таким типом шерсти.
#
# Среднее число просмотров:  205.0
# --------------------------
# ==================
#
# Название:
# ----------
# Вельш корги кардиган
#
# Описание:
# ----------
# Ждет своих самых любящих  пап и мам  очень веселый,игривый мальчик Ормай Джейкоб редкого окраса рыжий соболь, мальчик  перспективный для выставок,спорта и общения. Отлично выращен , хорошо социализирован , растет в семье с детьми и отлично относятся к людям и животным. У малыша клеймо, документы РКФ,прививка по возрасту. Разумный торг. На все вопросы о малышах отвечу по телефону. От пары чемпионов:
#
# Среднее число просмотров:  201.0
# --------------------------

# %% [markdown]
# Видно, что наибольшей популярностью пользуются попродистые собаки. Теперь рассмотрим наименее популярные объявления:

# %%
sorted_df = dataset.sort(['mean_count'], ascending=True)
for i in (sorted_df.index.tolist()[:10]):
    print('==================')
    print('\nНазвание: ')
    print('----------')
    print(sorted_df.loc[i,'title'])
    
    print('\nОписание: ')
    print('----------')
    print(sorted_df.loc[i,'description'])

    
    print('\nСреднее число просмотров: ',sorted_df.loc[i,'mean_count'])
    print('--------------------------')
# Out:
# ==================
#
# Название:
# ----------
# Метис дога Блек
#
# Описание:
# ----------
# Самый очаровательный пес во вселенной ждет свою семью!  Возраст полтора года, рост в холке более 55 см. Очень веселый и жизнерадостный, ориентирован на человека. При прогулке проблем не возникает, к поводку приучен. Хорошо ладит с другими собаками. Блэк очень осторожен и умен. Такому общительному и молодому псу в приюте очень тоскливо, и каждый приход волонтера для него настоящий праздник! Хочется, чтобы наш замечательный Блэк  обрел своего настоящего друга!
#
# Среднее число просмотров:  0.088768115942
# --------------------------
# ==================
#
# Название:
# ----------
# Милаха Лили ищет дом
#
# Описание:
# ----------
# Лили Добрая, очень ласковая, умная девочка. Возраст - 2,5 года. К другим собакам относится доброжелательно, очень тонко чувствует настроение человека и его отношение к себе. К поводку приучена, на прогулках всегда идет рядом. Когда смотришь в глаза Лили, понимаешь насколько она хочет тепла и настоящей заботы. Она, как и все здесь, ищет человека...Того, кто примет её в свой дом и одарит искренней любовью. А уж эта девочка, не сомневайтесь, ответит Вам с невероятной отдачей!
#
# Среднее число просмотров:  0.128787878788
# --------------------------
# ==================
#
# Название:
# ----------
# В Несси невозможно не влюбиться. (собака в дар)
#
# Описание:
# ----------
# Несси около 1,5 лет . Она активная, веселая и жизнерадостная девочка, по сути совсем ребенок. Стерилизована, чипирована и привита. Рост около 40-45 см в холке. Не влюбиться в нее просто невозможно! Ласковая, очень благодарная и совершенно ненавязчивая. К другим собакам дружелюбна, любит поиграть и побегать наперегонки. Очень тянется к человеку. Если вы захотите просто поговорить с ней, она будет нежно и преданно смотреть Вам в глаза и радоваться, что Вы у нее есть, хотя бы в эту самую минуту. Несси хочет найти себе одного, единственного хозяина, чтобы быть с ним рядом, провести в общении юность, зрелость и достойно встретить старость. Приглядитесь к ней, может быть Несси - это именно Ваша собака?
#
# Среднее число просмотров:  0.142335766423
# --------------------------
# ==================
#
# Название:
# ----------
# Дональд - отличный друг для хорошего человека
#
# Описание:
# ----------
# Дональд (Дон) - довольно крупный пёс. Очень активный и очень умный. А так же ласковый, добрый и внимательный. С собаками ладит, но в обиду себя не даст. На поводке ходит хорошо. Кастрирован, чипирован, здоров. Возраст около 2-3 лет. Рост около 50 см в холке. Дональд очень ждет своего хозяина в Кожуховском приюте и верит, что его скоро обязательно забирут домой!
#
# Среднее число просмотров:  0.183807439825
# --------------------------
# ==================
#
# Название:
# ----------
# Молодой фокстерьер для вязки
#
# Описание:
# ----------
# Породистый жесткошерстный фокстерьер 4 года (без документов) желает познакомится с дамой.
#
# Среднее число просмотров:  0.203852327448
# --------------------------
# ==================
#
# Название:
# ----------
# Лапушка циркачка друг для всей семьи в дар
#
# Описание:
# ----------
# Альма-молодая собачка, ей где-то 3 года, в холке 45 см. Альмочка умная, добрая активная, ласковая, задорная, послушная, добродушная. Она прекрасно контактирует с другими собачками, но первенство и внимание к себе не уступит и будет его отстаивать, грозно порычав, но в драку не вступая. Альмочка может стоять на задних лапках как настоящая циркачка, пританцовывая и подпрыгивая. Собираясь на прогулку, принесет поводок и будет его нести на прогулке, а также она за поводок выведет на прогулку свою подругу. Поддается дрессировке. Альма может и хочет учиться. Она просто умница и очаровашка. Будет прекрасным компаньоном и другом. Звоните и приезжайте знакомиться
#
# Среднее число просмотров:  0.220498614958
# --------------------------
# ==================
#
# Название:
# ----------
# Чудесная Ночка в добрые руки
#
# Описание:
# ----------
# Ночка - ласкуша, каких поискать. Надо видеть, как она ложиться на спину и подставляет животик для почесушек. Очень добрая собака с удивительно умными глазами. Совершенно ненавязчива. Умеет слушать. Сидит и смотрит так внимательно, как будто все понимает. Станет прекрасным другом, отлично подойдет в семью с детьми. Ходит на поводке, любит гулять, бегать и играть. К другим собакам благожелательна. Рост 40-45 см в холке. Стерилизована, привита, чипирована. Собака молодая, примерный возраст около двух-трех лет. Ночка находится в Кожуховском приюте с весны 2012 года, сидит в вольере с двумя своими братишками (или сестричками), которые очень запуганы и не идут на контакт. Очень надеюсь, что в скором времени найдется хозяин для этой чудесной девочки и ее ласковый теплый взгляд не успеет потухнуть, как у ее соседей по клетке.
#
# Среднее число просмотров:  0.222707423581
# --------------------------
# ==================
#
# Название:
# ----------
# Ромуш нежный и очень добрый мальчик
#
# Описание:
# ----------
# Москва и МО! Друзья! Есть люди с удивительной харизмой. Им не составляет труда стать центром внимания в незнакомой компании. Попадая в коллектив, им стоит только немножко осмотреться по сторонам, оценить каждого участника коллектива и влиться без труда очень гармонично, найдя ключик к каждому. И кажется, что Вы этого человека знали всю жизнь! И не успеваешь опомниться, как ты уже доверительно рассказал ему всю свою историю жизни, уже поплакал на плече. И тебе кажется, что даже легкого кивания головой в такт твоему повествованию, уже достаточно, потому что ты «выговорился» уже такому родному и близкому для тебя человеку. Ромуш. Наш Ромуш – тот самый «человек». Свой, родной, близкий. Если Вы любитель юмора, то рядом с Вами он мигом станет самым юморным юмористом и будет со знанием дела рассказывать очередные анекдоты или забавные случаи как Павел Воля. И он так увлечется, что Вы так и не поймете, где правда, а где фантазии, точнее литературные аллегории, которые только украшают его выступления :) Если на сегодняшний день Вы решили отдохнуть от внимания мужской половины человечества, то для Вас, милые барышни, Ромуш станет Вашим личным Эштоном Катчером. Тем красавчиком, рядом с которым Вы будете чувствовать себя влюбленной, а он будет вышагивать рядом, весело подмигивая Вам, потому что эта «игра» Вас обоих будет веселить. Если Вы любите домашний покой, то Ромуш тихо ляжет у Ваших ног и с удовольствием посмотрит с Вами фильм, который Вы потом непременно вместе обсудите за чашкой горячего шоколада с ватрушками. И с ним Вам будет очень уютно и тепло холодными вечерами. Если у Вас дети и Ваш дом похож на «детский дримлэнд», то Ромуш будет впереди всех бежать с криком «Банзай», тем самым забавляя детвору, которая будет просто пищать от восторга от их нового друга! Ну а если Вы интересный, самодостаточный мужчина, то красивый, атлетически сложенный Ромуш будет придавать Вашему тандему брутальную импозантность. И Вы непременно после каждой совместной прогулки будете на Вашем мужском совете обсуждать, с кем провести следующий вечер «Катя, Маша или Вера» :) Ну что можно сказать? Не парень, а находка! А если коротко, то Ромуш – нежный и очень добрый мальчик, который очень любит общаться и притягивать внимание, потому что самое страшное для него – это снова, как закончится волонтерский день, оказаться в приютской клетке, в которой он живет уже несколько лет. Ромушу 4 года, живет в приюте Солнцево, 50 см в холке, привит, здоров, кастрирован, прекрасно ходит на поводке и порхает как орел без него :) Звоните и приезжайте знакомиться с нашим юмористом, ценителем хорошего кино, верного друга всех детишек и просто красавцем Ромушом!
#
# Среднее число просмотров:  0.240223463687
# --------------------------
# ==================
#
# Название:
# ----------
# Пэнни-веселая собака в дар
#
# Описание:
# ----------
# Привет! Я так хочу каждый день открывать что-то интересное для нас с тобой! Ой, даже не представилась! Пэнни, 1-2 года, рост 55см. Я стройная и стерилизованная. Собака бесплатно (то есть я) – это самое правильное решение! Я так хочу дружить и дарить вам свою любовь! Я активная и легко стану компаньоном в любом деле! Люблю играть и дурачиться. Хорошо хожу на поводке и без него. Могу жить в квартире. А если у вас дом за городом, это тоже хорошо! Я не навязчивая, а очень даже самостоятельная! Я же все понимаю. Возьмите меня в свою семью! И мы будем открывать что-то новое и интересное вместе!
#
# Среднее число просмотров:  0.25
# --------------------------
# ==================
#
# Название:
# ----------
# Статный красавец 3года ищет дом
#
# Описание:
# ----------
# Москва.Малышу всего лишь  3 года и он ему очень нужен дом! Кастрирован.Привит.Невероятно добрый малый. Профессионально спит на диване, досконально умывает, крепко обнимает, учит команды с огромным удовольствием! Дружит со всеми собаками, знает правила поведения в доме, а так же тонкости игр с детьми. Анастасия
#
# Среднее число просмотров:  0.261224489796
# --------------------------

# %% [markdown]
# К сожалению, животные из приютов пользуются меньшей популярностью.

# %%
plt.hist((dataset['mean_count']), bins = 200)
# Out:
# (array([  1.60100000e+03,   6.71000000e+02,   3.70000000e+02,
#           2.37000000e+02,   1.93000000e+02,   1.42000000e+02,
#           8.50000000e+01,   8.00000000e+01,   5.30000000e+01,
#           5.10000000e+01,   4.50000000e+01,   3.50000000e+01,
#           3.10000000e+01,   2.60000000e+01,   2.50000000e+01,
#           2.40000000e+01,   1.60000000e+01,   1.80000000e+01,
#           1.60000000e+01,   1.40000000e+01,   9.00000000e+00,
#           6.00000000e+00,   6.00000000e+00,   5.00000000e+00,
#           8.00000000e+00,   1.10000000e+01,   3.00000000e+00,
#           5.00000000e+00,   7.00000000e+00,   4.00000000e+00,
#           3.00000000e+00,   5.00000000e+00,   4.00000000e+00,
#           6.00000000e+00,   4.00000000e+00,   4.00000000e+00,
#           4.00000000e+00,   2.00000000e+00,   0.00000000e+00,
#           3.00000000e+00,   1.00000000e+00,   6.00000000e+00,
#           2.00000000e+00,   0.00000000e+00,   4.00000000e+00,
#           1.00000000e+00,   3.00000000e+00,   1.00000000e+00,
#           2.00000000e+00,   3.00000000e+00,   3.00000000e+00,
#           0.00000000e+00,   3.00000000e+00,   1.00000000e+00,
#           1.00000000e+00,   2.00000000e+00,   2.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   2.00000000e+00,   1.00000000e+00,
#           1.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   1.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.00000000e+00]),
#  array([  8.87681159e-02,   3.15332428e+00,   6.21788043e+00,
#           9.28243659e+00,   1.23469928e+01,   1.54115489e+01,
#           1.84761051e+01,   2.15406612e+01,   2.46052174e+01,
#           2.76697736e+01,   3.07343297e+01,   3.37988859e+01,
#           3.68634420e+01,   3.99279982e+01,   4.29925543e+01,
#           4.60571105e+01,   4.91216667e+01,   5.21862228e+01,
#           5.52507790e+01,   5.83153351e+01,   6.13798913e+01,
#           6.44444475e+01,   6.75090036e+01,   7.05735598e+01,
#           7.36381159e+01,   7.67026721e+01,   7.97672283e+01,
#           8.28317844e+01,   8.58963406e+01,   8.89608967e+01,
#           9.20254529e+01,   9.50900091e+01,   9.81545652e+01,
#           1.01219121e+02,   1.04283678e+02,   1.07348234e+02,
#           1.10412790e+02,   1.13477346e+02,   1.16541902e+02,
#           1.19606458e+02,   1.22671014e+02,   1.25735571e+02,
#           1.28800127e+02,   1.31864683e+02,   1.34929239e+02,
#           1.37993795e+02,   1.41058351e+02,   1.44122908e+02,
#           1.47187464e+02,   1.50252020e+02,   1.53316576e+02,
#           1.56381132e+02,   1.59445688e+02,   1.62510245e+02,
#           1.65574801e+02,   1.68639357e+02,   1.71703913e+02,
#           1.74768469e+02,   1.77833025e+02,   1.80897582e+02,
#           1.83962138e+02,   1.87026694e+02,   1.90091250e+02,
#           1.93155806e+02,   1.96220362e+02,   1.99284918e+02,
#           2.02349475e+02,   2.05414031e+02,   2.08478587e+02,
#           2.11543143e+02,   2.14607699e+02,   2.17672255e+02,
#           2.20736812e+02,   2.23801368e+02,   2.26865924e+02,
#           2.29930480e+02,   2.32995036e+02,   2.36059592e+02,
#           2.39124149e+02,   2.42188705e+02,   2.45253261e+02,
#           2.48317817e+02,   2.51382373e+02,   2.54446929e+02,
#           2.57511486e+02,   2.60576042e+02,   2.63640598e+02,
#           2.66705154e+02,   2.69769710e+02,   2.72834266e+02,
#           2.75898822e+02,   2.78963379e+02,   2.82027935e+02,
#           2.85092491e+02,   2.88157047e+02,   2.91221603e+02,
#           2.94286159e+02,   2.97350716e+02,   3.00415272e+02,
#           3.03479828e+02,   3.06544384e+02,   3.09608940e+02,
#           3.12673496e+02,   3.15738053e+02,   3.18802609e+02,
#           3.21867165e+02,   3.24931721e+02,   3.27996277e+02,
#           3.31060833e+02,   3.34125389e+02,   3.37189946e+02,
#           3.40254502e+02,   3.43319058e+02,   3.46383614e+02,
#           3.49448170e+02,   3.52512726e+02,   3.55577283e+02,
#           3.58641839e+02,   3.61706395e+02,   3.64770951e+02,
#           3.67835507e+02,   3.70900063e+02,   3.73964620e+02,
#           3.77029176e+02,   3.80093732e+02,   3.83158288e+02,
#           3.86222844e+02,   3.89287400e+02,   3.92351957e+02,
#           3.95416513e+02,   3.98481069e+02,   4.01545625e+02,
#           4.04610181e+02,   4.07674737e+02,   4.10739293e+02,
#           4.13803850e+02,   4.16868406e+02,   4.19932962e+02,
#           4.22997518e+02,   4.26062074e+02,   4.29126630e+02,
#           4.32191187e+02,   4.35255743e+02,   4.38320299e+02,
#           4.41384855e+02,   4.44449411e+02,   4.47513967e+02,
#           4.50578524e+02,   4.53643080e+02,   4.56707636e+02,
#           4.59772192e+02,   4.62836748e+02,   4.65901304e+02,
#           4.68965861e+02,   4.72030417e+02,   4.75094973e+02,
#           4.78159529e+02,   4.81224085e+02,   4.84288641e+02,
#           4.87353197e+02,   4.90417754e+02,   4.93482310e+02,
#           4.96546866e+02,   4.99611422e+02,   5.02675978e+02,
#           5.05740534e+02,   5.08805091e+02,   5.11869647e+02,
#           5.14934203e+02,   5.17998759e+02,   5.21063315e+02,
#           5.24127871e+02,   5.27192428e+02,   5.30256984e+02,
#           5.33321540e+02,   5.36386096e+02,   5.39450652e+02,
#           5.42515208e+02,   5.45579764e+02,   5.48644321e+02,
#           5.51708877e+02,   5.54773433e+02,   5.57837989e+02,
#           5.60902545e+02,   5.63967101e+02,   5.67031658e+02,
#           5.70096214e+02,   5.73160770e+02,   5.76225326e+02,
#           5.79289882e+02,   5.82354438e+02,   5.85418995e+02,
#           5.88483551e+02,   5.91548107e+02,   5.94612663e+02,
#           5.97677219e+02,   6.00741775e+02,   6.03806332e+02,
#           6.06870888e+02,   6.09935444e+02,   6.13000000e+02]),
#  <a list of 200 Patch objects>)

# %%
# если цена указанна как 'Неуказана', 'Договорная' то она заменяется на 100р.
dataset['price'] = dataset['price'].apply(lambda x: 100 if x in ['Неуказана', 'Договорная'] else int(x))
dataset = dataset[dataset['price'] <= 500]
dataset.drop(['price'], axis = 1, inplace = True)
dataset.shape
# Out:
# (3384, 3)

# %% [markdown]
# Стемминг можно применить ко всему набору сразу, поскольку для работы он использует только данное конкретное слово

# %%
dataset['description'] = dataset['description'].apply(stemmer)

# %%
X_train, X_test, y_train, y_test  = train_test_split(dataset['description'],dataset['mean_count'], test_size=0.33)

# %% [markdown]
# Разбиение целевой переменной на 5 квартилей. Т.е. получили задачу многоклассовой классификации из 5 классов

# %%
y_train = pd.qcut(y_train, q= 5)

# %% [markdown]
# Рассмотрим baseline - qcut разбил выборку равномерно - по 454 объекта в каждом квартиле. Если всем объектам приписать какой-нибудь один класс, то качество будет 20%.

# %%
print(pd.value_counts(y_train))
print(pd.value_counts(y_train))
print('Baseline accuracy: ',454/y_train.shape[0])
# Out:
# (13.599, 324]      454
# [0.0888, 1.184]    454
# (5.334, 13.599]    453
# (2.436, 5.334]     453
# (1.184, 2.436]     453
# dtype: int64
# (13.599, 324]      454
# [0.0888, 1.184]    454
# (5.334, 13.599]    453
# (2.436, 5.334]     453
# (1.184, 2.436]     453
# dtype: int64
# Baseline accuracy:  0.20026466696074108

# %% [markdown]
# Сетка для поиска гиперпараметров.Поскольку интересно знать, какие слова влияют на посещаеомсть, было решенно не использовать LSA

# %%
parameters = {
    'vect__max_df': (0.5, 0.75,1),
    #'vect__max_features': (10000, 50000),
    #'vect__ngram_range': ((1, 2)),  # unigrams or bigrams
    #'tfidf__use_idf': (True,False),
    #'tfidf__norm': ('l2'),
    #'svd__n_components':(50,100,1000),
    "clf__max_depth": [3, None],
    "clf__max_features": [1, 3, 10],
    "clf__min_samples_split": [1, 3, 10],
    "clf__min_samples_leaf": [1, 3, 10],
    "clf__bootstrap": [True, False]
}

total_comb = 1
for i in parameters.values():
    total_comb *= len(i)
print('Всего комбинаций: ', total_comb)
# Out:
# Всего комбинаций:  324

# %% [markdown]
# В качестве классификатора - случайный лес.

# %%
pipe = Pipeline([('vect', CountVectorizer(stop_words=stop, ngram_range=(1, 2), max_features=10000)),
                 ('tfidf', TfidfTransformer(use_idf=True,norm='l2')),
                 #('svd', TruncatedSVD(algorithm='randomized')),
                 ('clf', RandomForestClassifier(n_estimators=500, verbose = False))]) 


grid_search = GridSearchCV(pipe, parameters, verbose=True, n_jobs = -1, cv = 5)
grid_search.fit(X_train, y_train)

print("Best score: %0.3f" % grid_search.best_score_)
print("Best parameters set:")
best_parameters = grid_search.best_estimator_.get_params()
for param_name in sorted(parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   47.8s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 1234 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 1620 out of 1620 | elapsed: 11.5min finished
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# Best score: 0.386
# Best parameters set:
# 	clf__bootstrap: False
# 	clf__max_depth: None
# 	clf__max_features: 3
# 	clf__min_samples_leaf: 3
# 	clf__min_samples_split: 1
# 	vect__max_df: 0.5

# %%
# Преобразование тестовой выборки в квартили
y_test = y_test.apply(y_transform)

# %%
print(classification_report(y_test,grid_search.predict(X_test)))
# Out:
#              precision    recall  f1-score   support
#
# (1.184, 2.436]       0.30      0.19      0.24       206
# (13.599, 324]       0.37      0.58      0.45       222
# (2.436, 5.334]       0.21      0.10      0.13       234
# (5.334, 13.599]       0.38      0.27      0.31       241
# [0.0888, 1.184]       0.44      0.72      0.54       214
#
# avg / total       0.34      0.37      0.33      1117

# %%
print(pd.crosstab(y_test,grid_search.predict(X_test)))
# Out:
# col_0            (1.184, 2.436]  (13.599, 324]  (2.436, 5.334]  (5.334, 13.599]  [0.0888, 1.184]
# mean_count
# (1.184, 2.436]               40             21              24               21              100
# (13.599, 324]                14            129              23               37               19
# (2.436, 5.334]               33             80              23               39               59
# (5.334, 13.599]              19            111              24               64               23
# [0.0888, 1.184]              28             12              13                6              155

# %% [markdown]
# Топ-10 слов, которые сильнее всего влияют на классификацию

# %%
feature_weights = {'name': grid_search.best_estimator_.named_steps['vect'].get_feature_names(),
                  'weight': grid_search.best_estimator_.named_steps['clf'].feature_importances_}

feature_weights = pd.DataFrame(data=feature_weights['weight'], index = feature_weights['name'], columns = ['weight'])
feature_weights.sort(['weight'], ascending=False, inplace=True)
feature_weights.head(10)
# Out:
#                  weight
# лет            0.005378
# см             0.005045
# собак          0.004336
# стерилизована  0.003811
# люб            0.003482
# окол           0.003441
# см холке       0.003116
# холк окол      0.002992
# поводке        0.002915
# приюте         0.002730

# %%
fig, ax = plt.subplots()
feature_weights.head(50).plot(ax=ax,kind = 'bar')
fig.autofmt_xdate()

# %% [markdown]
# ## Диаграммы рассеяния(scatterplots)

# %% [markdown]
# Вообще, этот этап должен быть в начале исследования, но поскольку у нас текст и сильно разреженная матрица объекты-признаки, то имеет смысл построить графики только для топ-7, в соответствии с информацией о важности признаков, полученной от случайного леса.

# %%
from sklearn.preprocessing import LabelEncoder

dataset_tfidf = pd.DataFrame(grid_search.best_estimator_.named_steps['vect'].transform(X_train).toarray())
dataset_tfidf.columns = grid_search.best_estimator_.named_steps['vect'].get_feature_names()
dataset_tfidf = dataset_tfidf[feature_weights.index.tolist()[:7]]

# поскольку у нас дискретные отсчеты, немного "размоем" значения, чтобы точки не ложились одна на другую:
for k in dataset_tfidf.keys():
    dataset_tfidf[k] = dataset_tfidf[k].apply(lambda x: int(x)+np.random.normal(0,0.08))

dataset_tfidf['target'] =(y_train)

seaborn.pairplot(dataset_tfidf, hue = 'target')

# %% [markdown]
# Видно, что желтые точки(интервал с максимальным числом просмотров) хорошо различаются от остальных

# %% [markdown]
# ## Кривые обучения

# %%
def plot_with_std(x, data, **kwargs):
        mu, std = data.mean(1), data.std(1)
        lines = plt.plot(x, mu, '-', **kwargs)
        plt.fill_between(x, mu - std, mu + std, edgecolor='none',
                         facecolor=lines[0].get_color(), alpha=0.2)
        
def plot_learning_curve(clf, X, y, scoring, cv=5):
 
    train_sizes = np.linspace(0.05, 1, 20)
    n_train, val_train, val_test = learning_curve(clf,
                                                  X, y, train_sizes, cv=cv,
                                                  scoring=scoring, n_jobs = -1)
    plot_with_std(n_train, val_train, label='training scores', c='green')
    plot_with_std(n_train, val_test, label='validation scores', c='red')
    plt.xlabel('Training Set Size'); plt.ylabel(scoring)
    plt.legend()

# %%
plot_learning_curve(grid_search.best_estimator_,X_train, y_train, scoring='f1_weighted', cv=10)

# %% [markdown]
# **Примечание:** иногда при разных запусках на валидационной кривой можно увидеть, что классификатор всегда отлично описывает обучающую выборку, но зазор между train и cv кривыми довльно большой. Скорее всего это индикатор переобучения и вот откуда оно взялось: в качестве классификатора передается pipeline, **гиперпараметры** которого были настроены ранее по той же обучающей выборке. Т.е. learning_curve конечно проводит обучение заново, но только для параметров случайного леса, а гиперпараметры остаются прежними. По хорошему, необходимо в learning_curve передать объект grid_search и для каждого размера обучающей выборки производить поиск по сетке, но это будет слишком долго для данной учебной задачи.

# %% [markdown]
# ## Выводы

# %% [markdown]
# 1. Построена модель прогнозирования среднего числа посещений объявления с качеством accuracy = 0.386, что почти в два раза больше, чем прогнозирование константным значением (accuracy = 0.20)
# 2. Точнее всего модель предсказывает значения, которые находятся в крайних интервалах - [0.0888, 1.222] и (13.193, 324]
# 3. Судя по значимости слов, люди обращают внимание на пол, возраст, медицинские и физиологические характеристики, умение гулять на поводке
# 4. Качество модели может быть улучшено, если к тексту добавить фотографии. Для извлечения признаков из фото можно попробовать использовать сверточные нейронные сети, например, AlexNet

# %% [markdown]
# ## Сылки

# %% [markdown]
# 1. [Text classification for russian language][1]
# + [Russian stemming algorithm][2]
# + [nltk.stem.snowball.RussianStemmer][3]
# + [Classification of text documents using sparse features][4]
#
#
# [1]: http://stackoverflow.com/questions/18011756/text-classification-for-russian-language
# [2]: http://snowball.tartarus.org/algorithms/russian/stemmer.html
# [3]: http://www.nltk.org/api/nltk.stem.html
# [4]: http://scikit-learn.org/stable/auto_examples/text/document_classification_20newsgroups.html
