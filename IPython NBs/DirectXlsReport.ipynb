# %% [markdown]
# Авторизация на Яндексе через requests

# %%
from requests import Session
import pandas as pd
import cookielib

# %%
session = Session()
session.cookies = cookielib.CookieJar()

# %%
URL_RET = 'https://direct.yandex.ru/registered/main.pl?cmd=showClients'
URL_PASSPORT = 'https://passport.yandex.ru/passport'

# %%
params = {'mode': 'auth',
                  'retpath': URL_RET}
data = {'login': 'Alexgrtula',
                'passwd': 'DhYwOHrW',
                'retpath': URL_RET}
response = session.post(URL_PASSPORT,
                                      params=params,
                                      data=data,
                                      allow_redirects=True)

# %%
CLIENT = 'avtozap4asti-ru-cubo'
CID = '16093119'
url = 'https://direct.yandex.ru/registered/01.12-31.12_main{0}.xls?m2=12&m1=12&y1=15&stat_type=custom&offline_stat=0&cmd=showCampStat&cid={0}&filter_position=&filter_phrase=&currency_archive=&d1=01&group=day&with_auto_added_phrases=1&stat_periods=2015-09-01%3A2015-12-31%2C2015-12-17%3A2015-12-31%2C2015-12-05%3A2015-12-31&y2=15&isStat=1&with_nds=1&group_by=page%2C%20phrase%2C%20position%2C%20date&d2=31&ulogin={1}&filter_page_target=search&filter_page=&goals=0&with_avg_position=1&online_stat=1&onpage=100&save_nds=1&xls=1'.format(CID,CLIENT)
resp = session.get(url)
output = open('d:\\test.xls', 'wb')
output.write(resp.content)
output.close()

# %%
df = pd.read_excel('d:\\test.xls',skiprows=4,skip_footer=1)

# %%
df[u'Кампания'] = CID
df[u'Клиент'] = CLIENT

# %%
df
# Out:
#        Площадка Тип площадки         Позиция  \
# 0        Яндекс    поисковая  спецразмещение
# 1        Яндекс    поисковая          прочее
# 2        Яндекс    поисковая  спецразмещение
# 3        Яндекс    поисковая  спецразмещение
# 4        Яндекс    поисковая  спецразмещение
# 5    go.mail.ru    поисковая  спецразмещение
# 6    go.mail.ru    поисковая  спецразмещение
# 7    go.mail.ru    поисковая  спецразмещение
# 8  www.bing.com    поисковая  спецразмещение
# 9  www.bing.com    поисковая  спецразмещение
#
#                                   Условие показа        Дата  Показы  Клики  \
# 0              купить запчасти mercedes в москве  31.12.2015       1      0
# 1              купить запчасти на skoda -октавия  29.12.2015       1      0
# 2                    магазин автозапчастей skoda  29.12.2015       1      0
# 3     магазин автозапчастей volkswagen -интернет  29.12.2015       1      0
# 4     магазин автозапчастей volkswagen -интернет  30.12.2015       2      0
# 5             "магазин автозапчастей volkswagen"  29.12.2015       1      0
# 6  купить запчасти на mercedes -москва -спринтер  28.12.2015       1      0
# 7     магазин автозапчастей volkswagen -интернет  29.12.2015       1      1
# 8       запчасти для volkswagen интернет магазин  31.12.2015       1      0
# 9     магазин автозапчастей volkswagen -интернет  31.12.2015       1      0
#
#    CTR (%)  * Расход (руб.) * Ср. цена клика (руб.) Ср. позиция показов  \
# 0        0             0.00                       -                   1
# 1        0             0.00                       -                   4
# 2        0             0.00                       -                   2
# 3        0             0.00                       -                   1
# 4        0             0.00                       -                   1
# 5        0             0.00                       -                   -
# 6        0             0.00                       -                   -
# 7      100            11.68                   11.68                   -
# 8        0             0.00                       -                   -
# 9        0             0.00                       -                   -
#
#   Ср. позиция кликов Глубина (стр.) Конверсии Конверсия (%)  \
# 0                  -              -         -             -
# 1                  -              -         -             -
# 2                  -              -         -             -
# 3                  -              -         -             -
# 4                  -              -         -             -
# 5                  -              -         -             -
# 6                  -              -         -             -
# 7                  -              2         0             0
# 8                  -              -         -             -
# 9                  -              -         -             -
#
#   * Цена цели (руб.) Рентабельность  Доход (руб.)  Кампания  \
# 0                  -              -             0  16093119
# 1                  -              -             0  16093119
# 2                  -              -             0  16093119
# 3                  -              -             0  16093119
# 4                  -              -             0  16093119
# 5                  -              -             0  16093119
# 6                  -              -             0  16093119
# 7                  -              -             0  16093119
# 8                  -              -             0  16093119
# 9                  -              -             0  16093119
#
#                  Клиент
# 0  avtozap4asti-ru-cubo
# 1  avtozap4asti-ru-cubo
# 2  avtozap4asti-ru-cubo
# 3  avtozap4asti-ru-cubo
# 4  avtozap4asti-ru-cubo
# 5  avtozap4asti-ru-cubo
# 6  avtozap4asti-ru-cubo
# 7  avtozap4asti-ru-cubo
# 8  avtozap4asti-ru-cubo
# 9  avtozap4asti-ru-cubo

# %%
pairs = [('avtozap4asti-ru-cubo','16093119'),('avtozap4asti-ru-cubo','16093105'),('avtozap4asti-ru-cubo','16093132'),('avtozap4asti-ru-cubo','16093125'),('avtozap4asti-ru-cubo','16009440'),('avtozap4asti-ru-cubo','16054179'),('avtozap4asti-ru-cubo','16009033'),('avtozap4asti-ru-cubo','16054170'),('c123btru-cubo','15733858'),('c123btru-cubo','15746190'),('nlv-ru-cubo','16040429'),('cubo-esis-ru','15362845'),('cubo-esis-ru','15364498'),('cubo-esis-ru','15229063'),('cubo-esis-ru','15233763'),('pravo-ved-cubo','15904805'),('pravo-ved-cubo','15950729')]
dataframes = []
for CLIENT,CID in pairs:
    print 'Process: campaign {0}'.format(CID)
    url = 'https://direct.yandex.ru/registered/01.12-31.12_main{0}.xls?m2=12&m1=12&y1=15&stat_type=custom&offline_stat=0&cmd=showCampStat&cid={0}&filter_position=&filter_phrase=&currency_archive=&d1=01&group=day&with_auto_added_phrases=1&stat_periods=2015-09-01%3A2015-12-31%2C2015-12-17%3A2015-12-31%2C2015-12-05%3A2015-12-31&y2=15&isStat=1&with_nds=1&group_by=page%2C%20phrase%2C%20position%2C%20date&d2=31&ulogin={1}&filter_page_target=search&filter_page=&goals=0&with_avg_position=1&online_stat=1&onpage=100&save_nds=1&xls=1'.format(CID,CLIENT)
    resp = session.get(url)
    output = open('d:\\direct_data\\c{0}.xls'.format(CID), 'wb')
    output.write(resp.content)
    output.close()
    df = pd.read_excel('d:\\direct_data\\c{0}.xls'.format(CID),skiprows=4,skip_footer=1)
    df[u'Кампания'] = int(CID)
    df[u'Клиент'] = CLIENT
    dataframes.append(df)
total_df = pd.concat(dataframes)
total_df.to_excel('D:\\concat2.xlsx', sheet_name='Sheet1')
# Out:
# Process: campaign 16093119
# Process: campaign 16093105
# Process: campaign 16093132
# Process: campaign 16093125
# Process: campaign 16009440
# Process: campaign 16054179
# Process: campaign 16009033
# Process: campaign 16054170
# Process: campaign 15733858
# Process: campaign 15746190
# Process: campaign 16040429
# Process: campaign 15362845
# Process: campaign 15364498
# Process: campaign 15229063
# Process: campaign 15233763
# Process: campaign 15904805
# Process: campaign 15950729
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-103-1437881443e8> in <module>()
#      13     dataframes.append(df)
#      14 total_df = pd.concat(dataframes)
# ---> 15 total_df.to_excel('D:\\concat2.xlsx', sheet_name='Sheet1')
#
# C:\Users\aleksey.makarov\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\core\frame.pyc in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep)
#    1274                                  startrow=startrow, startcol=startcol)
#    1275         if need_save:
# -> 1276             excel_writer.save()
#    1277
#    1278     def to_stata(
#
# C:\Users\aleksey.makarov\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\io\excel.pyc in save(self)
#    1296         Save workbook to disk.
#    1297         """
# -> 1298         return self.book.close()
#    1299
#    1300     def write_cells(self, cells, sheet_name=None, startrow=0, startcol=0):
#
# C:\Users\aleksey.makarov\AppData\Local\Continuum\Anaconda\lib\site-packages\xlsxwriter\workbook.pyc in close(self)
#     293         if not self.fileclosed:
#     294             self.fileclosed = 1
# --> 295             self._store_workbook()
#     296
#     297     def set_properties(self, properties):
#
# C:\Users\aleksey.makarov\AppData\Local\Continuum\Anaconda\lib\site-packages\xlsxwriter\workbook.pyc in _store_workbook(self)
#     522
#     523         xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
# --> 524                             allowZip64=self.allow_zip64)
#     525
#     526         # Add XML sub-files to the Zip file with their Excel filename.
#
# C:\Users\aleksey.makarov\AppData\Local\Continuum\Anaconda\lib\zipfile.pyc in __init__(self, file, mode, compression, allowZip64)
#     754             modeDict = {'r' : 'rb', 'w': 'wb', 'a' : 'r+b'}
#     755             try:
# --> 756                 self.fp = open(file, modeDict[mode])
#     757             except IOError:
#     758                 if mode == 'a':
#
# IOError: [Errno 13] Permission denied: 'D:\\concat2.xlsx'

# %%
total_df = pd.concat(dataframes)
total_df.to_excel('D:\\concat2.xlsx', sheet_name='Sheet1')

# %%
df2
# Out:
#       Площадка Тип площадки         Позиция  \
# 0       Яндекс    поисковая  спецразмещение
# 1       Яндекс    поисковая  спецразмещение
# 2       Яндекс    поисковая  спецразмещение
# 3       Яндекс    поисковая  спецразмещение
# 4       Яндекс    поисковая  спецразмещение
# 5       Яндекс    поисковая  спецразмещение
# 6       Яндекс    поисковая  спецразмещение
# 7       Яндекс    поисковая  спецразмещение
# 8       Яндекс    поисковая  спецразмещение
# 9       Яндекс    поисковая  спецразмещение
# 10      Яндекс    поисковая  спецразмещение
# 11      Яндекс    поисковая  спецразмещение
# 12      Яндекс    поисковая  спецразмещение
# 13      Яндекс    поисковая  спецразмещение
# 14      Яндекс    поисковая  спецразмещение
# 15      Яндекс    поисковая          прочее
# 16      Яндекс    поисковая  спецразмещение
# 17      Яндекс    поисковая  спецразмещение
# 18      Яндекс    поисковая  спецразмещение
# 19      Яндекс    поисковая  спецразмещение
# 20      Яндекс    поисковая          прочее
# 21      Яндекс    поисковая  спецразмещение
# 0                    2                  -              -         -
# 1                    1                  -              -         -
# 2                    1                  -              -         -
# 3                    3                  3              1         0
# 4                    2                  -              -         -
# 5                    2                  -              -         -
# 6                    2                  -              -         -
# 7                    2                  -              -         -
# 8                    3                  -              -         -
# 9                    2                  -              -         -
# 10                   1                  -              -         -
# 11                2.33                  -              -         -
# 12                1.67                  -              -         -
# 13                   2                  -              -         -
# 14                   3                  -              -         -
# 15                   -                  -              -         -
# 16                   2                  -              -         -
# 17                   3                  3              1         0
# 18                   3                  -              -         -
# 19                   -                  -              -         -
# 20                   4                  -              -         -
# 21                   3                  -              -         -
# 22                   -                  -              -         -
# 23                   -                  -              -         -
# 24                   -                  -              -         -
# 25                   -                  -              -         -
# 26                   -                  -              -         -
#
#    Конверсия (%) * Цена цели (руб.) Рентабельность  Доход (руб.)  Кампания
# 0              -                  -              -             0  15950729
# 1              -                  -              -             0  15950729
# 2              -                  -              -             0  15950729
# 3              0                  -              -             0  15950729
# 4              -                  -              -             0  15950729
# 5              -                  -              -             0  15950729
# 6              -                  -              -             0  15950729
# 7              -                  -              -             0  15950729
# 8              -                  -              -             0  15950729
# 9              -                  -              -             0  15950729
# 10             -                  -              -             0  15950729
# 11             -                  -              -             0  15950729
# 12             -                  -              -             0  15950729
# 13             -                  -              -             0  15950729
# 14             -                  -              -             0  15950729
# 15             -                  -              -             0  15950729
# 16             -                  -              -             0  15950729
# 17             0                  -              -             0  15950729
# 18             -                  -              -             0  15950729
# 19             -                  -              -             0  15950729
# 20             -                  -              -             0  15950729
# 21             -                  -              -             0  15950729
# 22             -                  -              -             0  15950729
# 23             -                  -              -             0  15950729
# 24             -                  -              -             0  15950729
# 25             -                  -              -             0  15950729
# 26             -                  -              -             0  15950729

# %%
pd.concat([df1,df2]).to_excel('D:\\concat.xlsx', sheet_name='Sheet1')

# %%
import os
from datetime import datetime
import random,string

# %%
dirname = datetime.now().strftime("%y-%m-%d_%H-%M-%S_") + ''.join(random.SystemRandom().choice(string.ascii_uppercase + string.digits) for _ in range(5))
newpath = r'D:\direct_data\{0}'.format(dirname) 
if not os.path.exists(newpath):
    os.makedirs(newpath)

# %%
#!/usr/bin/python
#coding=utf-8
from requests import Session
import pandas as pd
import cookielib,os,random,string
from datetime import datetime

URL_RET = 'https://direct.yandex.ru/registered/main.pl?cmd=showClients'
URL_PASSPORT = 'https://passport.yandex.ru/passport'

class DirectData(object):
	"""Get reports from Yandex Direct by Login-CampaignID tuples"""

	def __init__(self, login, password):
		self._login = login
		self._password = password
		self._session = Session()
		self._session.cookies = cookielib.CookieJar()

	def _auth(self):
		params = {'mode': 'auth',
				  'retpath': URL_RET}
		data = {'login': self._login,
				'passwd': self._password,
				'retpath': URL_RET}
		response = self._session.post(URL_PASSPORT,
			params=params,
			data=data,
			allow_redirects=True)

	def _get_report_content(self,url,client,campaignId):
		mod_url = url.format(campaignId,client)
		resp = self._session.get(mod_url)
		return resp.content

# %%
dd = DirectData('Alexgrtula','DhYwOHrW')

# %%
dd._auth()
dd._session.cookies
# Out:
# <CookieJar[Cookie(version=0, name='L', value='e0BHSUteWlAGCWpfb3ZKbW0FDnB1Q1cDcD8VMjdHLD44Kg==.1452518061.12157.3993.a319815b22b724751570db7f23d821c7', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=2147483647, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='Session_id', value='3:1452518061.5.0.1452518061137:wiT0Vw:51.0|135139388.0.2|139719.605648.ejjRTaZ3SqCQ2M-GYeT0W5Zn5Bg', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=2147483647, discard=False, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='sessionid2', value='3:1452518061.5.0.1452518061137:wiT0Vw:51.1|135139388.0.2|139719.910631.8U2tIZfR3JPkuwok0fPpsjHL54c', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=2147483647, discard=False, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='yandex_login', value='Alexgrtula', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=2147483647, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='yandexuid', value='813898521452518061', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=1767878057, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='yp', value='1767878061.udn.cDpBbGV4Z3J0dWxh', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=2147483647, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='ys', value='udn.cDpBbGV4Z3J0dWxh', port=None, port_specified=False, domain='.yandex.ru', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={}, rfc2109=False), Cookie(version=0, name='pf', value='eyJmbGFzaCI6e319', port=None, port_specified=False, domain='passport.yandex.ru', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'httponly': None}, rfc2109=False), Cookie(version=0, name='pf.sig', value='WEkihpon3qfXt708UtZSzfT2k62TloAdz1jg6_iLs5Q', port=None, port_specified=False, domain='passport.yandex.ru', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'httponly': None}, rfc2109=False)]>

# %%
CLIENT = 'avtozap4asti-ru-cubo'
CID = '16093119'

print dd._get_report_content('https://direct.yandex.ru/registered/01.12-31.12_main{0}.xls?m2=12&m1=12&y1=15&stat_type=custom&offline_stat=0&cmd=showCampStat&cid={0}&filter_position=&filter_phrase=&currency_archive=&d1=01&group=day&with_auto_added_phrases=1&stat_periods=2015-09-01%3A2015-12-31%2C2015-12-17%3A2015-12-31%2C2015-12-05%3A2015-12-31&y2=15&isStat=1&with_nds=1&group_by=page%2C%20phrase%2C%20position%2C%20date&d2=31&ulogin={1}&filter_page_target=search&filter_page=&goals=0&with_avg_position=1&online_stat=1&onpage=100&save_nds=1&xls=1',CLIENT,CID)
# Out:
# �AB�=\5�08X�"1���Arial1���Arial1���Arial1���Arial1���Arial1���Arial1���Arial1���Arial1���Tahoma1��Arial1���Arial1���Arial��� � ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� � � �+�� �� �)�� �� �,�� �� �*�� �� �	�� �� �
# ;>I04:0"8? ?;>I04:8>78F8O#A;>285 ?>:0700B0/=45:A	?>8A:>20OA?5F@07<5I5=85!:C?8BL 70?G0AB8 mercedes 2 <>A:25
# 31.12.2015?@>G55!:C?8BL 70?G0AB8 =0 skoda ->:B028O
# 29.12.2015<03078= 02B>70?G0AB59 skoda*<03078= 02B>70?G0AB59 volkswagen -8=B5@=5B
# 30.12.2015
# go.mail.ru""<03078= 02B>70?G0AB59 volkswagen"-:C?8BL 70?G0AB8 =0 mercedes -<>A:20 -A?@8=B5@
# +j	K�
# �
# }�}�}�}�}��
# �
# �
# �
# �
# �
# �
# �
# �
# �
# 		�
#
#
# �
# �
# �
# �
# �
# �
# ���Q��?�
#
# @�
# �
# �
# �
# �
# �
# �
# �
# �
# �
# �
# �
# 	�
#
# �
# 	�
#
# �
# �
# �
# �
# �
# �
# �
# �
# �
# �
# �
#
# �?�
# �
# �
# �
# �
# �
# �
# �
# �
# �
# �
# �
#
# @�
# �
# �
# �
# �
# �
# �
# �
# �
# �
# �
# �
#
# @�
# �
# �
# �
# �
# �
# �
# �
# �
# �
#  �
# �
#
# �?�
# �
# �
# �
# �
# �
# �
# 	�
# 	�
# 	�
# 	 �
# �
#
# �?�
# 	�
# 	�
# �
# 	�
# 	�
# 		�
#
# "�
#
# �
#
# �
#
# #�
#
#
# �?
#
#
# �
#
# 	�
#
#
# �
#
# �
#
# �
#
# �
#
# �
#
# �
#
#
# �
# "�
# �
# �
# $�
# �
# 	�
#
# �
# �
# �
# �
# �
# �
# �
# "�
# �
# �
#  �
# \���(\'@	\���(\'@�
#
# �
# �
# �
# �
# &�
# �
# �
# '�
# �
# 	�
#
# �
# �
# �
# �
# �
# �
# �
# &�
# �
# �
#  �
# �
# 	�
#
# �
# �
# �
# �
# �
# �
# �
# (>�@A
#
#
# ����������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-135-e591ab3a40c6> in <module>()
# ----> 1 dd._get_report_content.mod_url
#
# AttributeError: 'function' object has no attribute 'mod_url'

# %%
#!/usr/bin/python
#coding=utf-8
from requests import Session
import pandas as pd
import cookielib,os,random,string
from datetime import datetime
import re

URL_RET = 'https://direct.yandex.ru/registered/main.pl?cmd=showClients'
URL_PASSPORT = 'https://passport.yandex.ru/passport'

class DirectData(object):
	"""Get reports from Yandex Direct by Login-CampaignID tuples"""

	def __init__(self, login, password):
		self._login = login
		self._password = password
		self._session = Session()
		self._session.cookies = cookielib.CookieJar()
		self._auth()

	def _auth(self):
		params = {'mode': 'auth',
				  'retpath': URL_RET}
		data = {'login': self._login,
				'passwd': self._password,
				'retpath': URL_RET}
		response = self._session.post(URL_PASSPORT,
			params=params,
			data=data,
			allow_redirects=True)

	def _create_url_template(self,url):
		url = re.sub('main.*\.xls','main{0}.xls',re.sub('&cid=(\d)*.','&cid={0}&',re.sub('&ulogin=[a-z0-9-]*','&ulogin={1}',url)))
		return url

	def _get_report_content(self,url,client,campaignId):
		url = self._create_url_template(url)
		resp = self._session.get(url.format(campaignId,client))
		return resp.content

# %%
dd = DirectData('Alexgrtula','DhYwOHrW')

# %%
dd._auth()

# %%
url = 'https://direct.yandex.ru/registered/04.01-11.01_main16009033.xls?filter_banner=&isStat=1&with_avg_position=1&m2=01&ulogin=avtozap4asti-ru-cubo&cmd=showCampStat&filter_gender=&stat_type=custom&filter_age=&d2=11&y1=16&filter_phrase=&filter_geo=&online_stat=1&filter_page_target=&goals=0&cid=16009033&filter_retargeting=&filter_page=&filter_tag=&offline_stat=0&with_auto_added_phrases=1&d1=04&filter_position=&group=day&group_by=tag%2C%20adgroup%2C%20banner%2C%20page%2C%20phrase%2C%20retargeting%2C%20geo%2C%20position%2C%20image%2C%20device_type%2C%20gender%2C%20age%2C%20date&y2=16&save_nds=1&filter_device_type=&filter_image=&stat_periods=2015-12-09%3A2016-01-03%2C2015-12-01%3A2016-01-11%2C2016-01-01%3A2016-01-11&with_nds=1&m1=01&filter_adgroup=&currency_archive=&onpage=100&xls=1'
CID = 16093119
x = dd._get_report_content(url,CLIENT,CID)
print x
# Out:
# �AB�=\5�08X�"1���Arial1���Arial1���Arial1���Arial1���Arial1���Arial1���Arial1���Arial1���Tahoma1��Arial1���Arial1���Arial1��Arial��� � ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� � � �+�� �� �)�� �� �,�� �� �*�� �� �	�� �� �
# !� �!� �#� ��������������������8�������������������������������3f������ff���f����������������������������������̙��̙3f�3���������fff����3f3�f333�3�3f33�333�$[0AB5@ >BGQB>2���
# ?;0=H5BK65=A:89>B 35 4> 44<03078= 70?G0AB59 audi(>A:20 (1>;55 B>G=> @538>= =5 >?@545;Q=)
# 10.01.2016M-1589625210A?5F@07<5I5=8545A:B>?<C6A:>9>B 25 4> 34(70?G0AB8 4;O volkswagen 8=B5@=5B <03078=
# 06.01.2016M-1589625223	<>18;L=K5-:C?8BL 70?G0AB8 =0 mercedes -<>A:20 -A?@8=B5@>@>;Q2
# 09.01.2016=5 >?@545;5=M-1589625292)<03078= 70?G0AB59 =0 volkswagen -8=B5@=5BAB@0KB8I8M-1589625318""<03078= 02B>70?G0AB59 volkswagen"
# 08.01.2016>B 18 4> 24*<03078= 02B>70?G0AB59 volkswagen -8=B5@=5Bgorod.yandex.ruwww.bing.com2>A:20 8 >1;0ABL (1>;55 B>G=> @538>= =5 >?@545;Q=)
# 07.01.2016M-1589625323!:C?8BL 70?G0AB8 =0 skoda ->:B028O
# go.mail.ruM-1589625328&70?G0AB8 4;O mercedes 8=B5@=5B <03078=M-1589625335:C?8BL 70?G0AB8 skoda octavia
# %	��	Y�
# ��
# }�}�}�
# }�
# }�}�}�}�
# �}		�}
#
# ��
# �
# �
# �
# �
# �
# �
# �
# �
# �
# 		�
#
#
# �
# �
# �
# �
# �
# �
# R���2@3@@�����5@ףp=
#
# ףp=
# �?	H�z�G�?
# @�
# �
# �
# �
# �
# �
# �
# �
# �
# �
# �
# �
# 	�
#
# �
# �
# �
# �
# �
# �
# �
# �
# �
# �
# 	�
#
# �
# �
# �
# �
# �
# �
#  �
# !@Ms$�A�
# "�
# #�
# $�
# %�
# &�
# '�
# 	(�
#
# )�
# *�
# +�
# ,@�
# @�
# �
# �
# �
# �
# �
# �
#  �
# !�Ps$�A�
# -�
# #�
# $�
# .�
# &�
# /�
# 	0�
#
# 1�
# 2�
# +�
# 3�?�?Y@�p=
# ��C@�p=
# @�
# �
# �
#  �
# !@Us$�A�
# 4�
# #�
# $�
# .�
# &�
# 5�
# 	0�
������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������

# %%
output = open('d:\\test2.xls', 'wb')
output.write(x)
output.close()

# %%
class FileWriter(object):
	"""Create folders and write xls-files with data"""
	def __init__(self, mainFolder):
		uniqueName = datetime.now().strftime("%y-%m-%d_%H-%M-%S_") + ''.join(random.SystemRandom().choice(string.ascii_uppercase + string.digits) for _ in range(5))
		if mainFolder[-1] != '\\':
			mainFolder += '\\'
		self._folderPath = mainFolder + uniqueName
		if not os.path.exists(self._folderPath):
			os.makedirs(self._folderPath)

	def _write_data_to_xls(self,data,campaignId):
		path = '{0}\{1}.xls'.format(self._folderPath,campaignId)
		print path
		output = open(path, 'wb')
		output.write(data)
		output.close()

# %%
fw = FileWriter('D:\direct_data\df')
print fw._folderPath
fw._write_data_to_xls(x,CID)
# Out:
# D:\direct_data\df\16-01-11_17-28-04_9MPH0
# D:\direct_data\df\16-01-11_17-28-04_9MPH0\16093119.xls

# %%
fw._write_data_to_xls(x,CID+1)
# Out:
# D:\direct_data\df\16-01-11_17-28-04_9MPH0\16093120.xls

# %%
print x
# Out:
# �AB�=\5�08X�"1���Arial1���Arial1���Arial1���Arial1���Arial1���Arial1���Arial1���Arial1���Tahoma1��Arial1���Arial1���Arial1��Arial��� � ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� ��� �� � � �+�� �� �)�� �� �,�� �� �*�� �� �	�� �� �
# !� �!� �#� ��������������������8�������������������������������3f������ff���f����������������������������������̙��̙3f�3���������fff����3f3�f333�3�3f33�333�$[0AB5@ >BGQB>2���
# ?;0=H5BK65=A:89>B 35 4> 44<03078= 70?G0AB59 audi(>A:20 (1>;55 B>G=> @538>= =5 >?@545;Q=)
# 10.01.2016M-1589625210A?5F@07<5I5=8545A:B>?<C6A:>9>B 25 4> 34(70?G0AB8 4;O volkswagen 8=B5@=5B <03078=
# 06.01.2016M-1589625223	<>18;L=K5-:C?8BL 70?G0AB8 =0 mercedes -<>A:20 -A?@8=B5@>@>;Q2
# 09.01.2016=5 >?@545;5=M-1589625292)<03078= 70?G0AB59 =0 volkswagen -8=B5@=5BAB@0KB8I8M-1589625318""<03078= 02B>70?G0AB59 volkswagen"
# 08.01.2016>B 18 4> 24*<03078= 02B>70?G0AB59 volkswagen -8=B5@=5Bgorod.yandex.ruwww.bing.com2>A:20 8 >1;0ABL (1>;55 B>G=> @538>= =5 >?@545;Q=)
# 07.01.2016M-1589625323!:C?8BL 70?G0AB8 =0 skoda ->:B028O
# go.mail.ruM-1589625328&70?G0AB8 4;O mercedes 8=B5@=5B <03078=M-1589625335:C?8BL 70?G0AB8 skoda octavia
# %	��	Y�
# ��
# }�}�}�
# }�
# }�}�}�}�
# �}		�}
#
# ��
# �
# �
# �
# �
# �
# �
# �
# �
# �
# 		�
#
#
# �
# �
# �
# �
# �
# �
# R���2@3@@�����5@ףp=
#
# ףp=
# �?	H�z�G�?
# @�
# �
# �
# �
# �
# �
# �
# �
# �
# �
# �
# �
������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������������

# %% [markdown]
# <b>Hello!</b>

# %%
from requests import Session
import pandas as pd
import cookielib,os,random,string
from datetime import datetime
import re

URL_RET = 'https://direct.yandex.ru/registered/main.pl?cmd=showClients'
URL_PASSPORT = 'https://passport.yandex.ru/passport'

class DirectData(object):
	"""Get reports from Yandex Direct by Login-CampaignID tuples"""

	def __init__(self, login, password):
		self._login = login
		self._password = password
		self._session = Session()
		self._session.cookies = cookielib.CookieJar()
		self._auth()

	def _auth(self):
		params = {'mode': 'auth',
				  'retpath': URL_RET}
		data = {'login': self._login,
				'passwd': self._password,
				'retpath': URL_RET}
		response = self._session.post(URL_PASSPORT,
			params=params,
			data=data,
			allow_redirects=True)

	def _create_url_template(self,url):
		url = re.sub('main.*\.xls','main{0}.xls',re.sub('&cid=(\d)*.','&cid={0}&',re.sub('&ulogin=[a-z0-9-]*','&ulogin={1}',url)))
		return url

	def _get_report_content(self, url, client, campaignId):
		url = self._create_url_template(url)
		resp = self._session.get(url.format(campaignId,client))
		return resp.content

class FileWriter(object):
	"""Create folders and write xls-files with data"""
	def __init__(self, mainFolder):
		uniqueName = datetime.now().strftime("%y-%m-%d_%H-%M-%S_") + ''.join(random.SystemRandom().choice(string.ascii_uppercase + string.digits) for _ in range(5))
		if mainFolder[-1] != '\\':
			mainFolder += '\\'
		self._folderPath = mainFolder + uniqueName
		if not os.path.exists(self._folderPath):
			os.makedirs(self._folderPath)

	def _write_data_to_xls(self, data, campaignId):
		path = '{0}\\{1}.xls'.format(self._folderPath,campaignId)
		print path
		output = open(path, 'wb')
		output.write(data)
		output.close()

class PandasDataFrame(object):
	"""Read xls-files and concatenate in one file"""

	def __init__(self, folderPath):
		self._folderPath = folderPath
		self._dfs = []

	def _xls_to_df(self, client, campaignId):
		df = pd.read_excel('{0}\\{1}.xls'.format(self._folderPath,campaignId),skiprows=4,skip_footer=1)
		df[u'Кампания'] = campaignId
		df[u'Клиент'] = client
		self._dfs.append(df)

	def _concat_dfs_to_xls(self):
		uniqueName = datetime.now().strftime("%y-%m-%d_%H-%M-%S")
		total_df = pd.concat(self._dfs)
		total_df.to_excel('{0}\\{1}.xlsx'.format(self._folderPath,uniqueName), sheet_name='Data')

# %%
pairs = [('avtozap4asti-ru-cubo','16093119'),('avtozap4asti-ru-cubo','16093105'),('avtozap4asti-ru-cubo','16093132'),('avtozap4asti-ru-cubo','16093125'),('avtozap4asti-ru-cubo','16009440'),('avtozap4asti-ru-cubo','16054179'),('avtozap4asti-ru-cubo','16009033'),('avtozap4asti-ru-cubo','16054170'),('c123btru-cubo','15733858'),('c123btru-cubo','15746190'),('nlv-ru-cubo','16040429'),('cubo-esis-ru','15362845'),('cubo-esis-ru','15364498'),('cubo-esis-ru','15229063'),('cubo-esis-ru','15233763'),('pravo-ved-cubo','15904805'),('pravo-ved-cubo','15950729')]
path = 'D:\\direct_data\\'
dd = DirectData('Alexgrtula','DhYwOHrW')
fw = FileWriter(path)
pdf = PandasDataFrame(fw._folderPath)
url = 'https://direct.yandex.ru/registered/04.01-11.01_main16009033.xls?filter_banner=&isStat=1&with_avg_position=1&m2=01&ulogin=avtozap4asti-ru-cubo&cmd=showCampStat&filter_gender=&stat_type=custom&filter_age=&d2=11&y1=16&filter_phrase=&filter_geo=&online_stat=1&filter_page_target=&goals=0&cid=16009033&filter_retargeting=&filter_page=&filter_tag=&offline_stat=0&with_auto_added_phrases=1&d1=04&filter_position=&group=day&group_by=tag%2C%20adgroup%2C%20banner%2C%20page%2C%20phrase%2C%20retargeting%2C%20geo%2C%20position%2C%20image%2C%20device_type%2C%20gender%2C%20age%2C%20date&y2=16&save_nds=1&filter_device_type=&filter_image=&stat_periods=2015-12-09%3A2016-01-03%2C2015-12-01%3A2016-01-11%2C2016-01-01%3A2016-01-11&with_nds=1&m1=01&filter_adgroup=&currency_archive=&onpage=100&xls=1'
for CLIENT,CID in pairs:
    print 'Process: campaign {0}'.format(CID)
    content = dd._get_report_content(url,CLIENT,CID)
    fw._write_data_to_xls(content,CID)
    pdf._xls_to_df(CLIENT,CID)
pdf._concat_dfs_to_xls()
# Out:
# Process: campaign 16093119
# D:\direct_data\16-01-11_20-57-07_K0CG2\16093119.xls
# Process: campaign 16093105
# D:\direct_data\16-01-11_20-57-07_K0CG2\16093105.xls
# Process: campaign 16093132
# D:\direct_data\16-01-11_20-57-07_K0CG2\16093132.xls
# Process: campaign 16093125
# D:\direct_data\16-01-11_20-57-07_K0CG2\16093125.xls
# Process: campaign 16009440
# D:\direct_data\16-01-11_20-57-07_K0CG2\16009440.xls
# Process: campaign 16054179
# D:\direct_data\16-01-11_20-57-07_K0CG2\16054179.xls
# Process: campaign 16009033
# D:\direct_data\16-01-11_20-57-07_K0CG2\16009033.xls
# Process: campaign 16054170
# D:\direct_data\16-01-11_20-57-07_K0CG2\16054170.xls
# Process: campaign 15733858
# D:\direct_data\16-01-11_20-57-07_K0CG2\15733858.xls
# Process: campaign 15746190
# D:\direct_data\16-01-11_20-57-07_K0CG2\15746190.xls
# Process: campaign 16040429
# D:\direct_data\16-01-11_20-57-07_K0CG2\16040429.xls
# Process: campaign 15362845
# D:\direct_data\16-01-11_20-57-07_K0CG2\15362845.xls
# Process: campaign 15364498
# D:\direct_data\16-01-11_20-57-07_K0CG2\15364498.xls
# Process: campaign 15229063
# D:\direct_data\16-01-11_20-57-07_K0CG2\15229063.xls
# Process: campaign 15233763
# D:\direct_data\16-01-11_20-57-07_K0CG2\15233763.xls
# Process: campaign 15904805
# D:\direct_data\16-01-11_20-57-07_K0CG2\15904805.xls
# Process: campaign 15950729
# D:\direct_data\16-01-11_20-57-07_K0CG2\15950729.xls

# %%
data = '''avtozap4asti-ru-cubo	16093119
avtozap4asti-ru-cubo	16093105
avtozap4asti-ru-cubo	16093132
avtozap4asti-ru-cubo	16093125
avtozap4asti-ru-cubo	16009440
avtozap4asti-ru-cubo	16054179
avtozap4asti-ru-cubo	16009033
avtozap4asti-ru-cubo	16054170
c123btru-cubo	15733858
c123btru-cubo	15746190
nlv-ru-cubo	16040429
cubo-esis-ru	15362845
cubo-esis-ru	15364498
cubo-esis-ru	15229063
cubo-esis-ru	15233763
pravo-ved-cubo	15904805
pravo-ved-cubo	15950729
'''

# %%
n_separated_data = data.split('\n')
pairs = []
for item in n_separated_data:
    tab_separated_data = item.split('\t')
    if len(tab_separated_data) != 2:
        continue
    pairs.append((tab_separated_data[0],tab_separated_data[1]))

# %%
pairs
# Out:
# [('avtozap4asti-ru-cubo', '16093119'),
#  ('avtozap4asti-ru-cubo', '16093105'),
#  ('avtozap4asti-ru-cubo', '16093132'),
#  ('avtozap4asti-ru-cubo', '16093125'),
#  ('avtozap4asti-ru-cubo', '16009440'),
#  ('avtozap4asti-ru-cubo', '16054179'),
#  ('avtozap4asti-ru-cubo', '16009033'),
#  ('avtozap4asti-ru-cubo', '16054170'),
#  ('c123btru-cubo', '15733858'),
#  ('c123btru-cubo', '15746190'),
#  ('nlv-ru-cubo', '16040429'),
#  ('cubo-esis-ru', '15362845'),
#  ('cubo-esis-ru', '15364498'),
#  ('cubo-esis-ru', '15229063'),
#  ('cubo-esis-ru', '15233763'),
#  ('pravo-ved-cubo', '15904805'),
#  ('pravo-ved-cubo', '15950729')]

# %%
URL_RET = 'https://direct.yandex.ru/registered/main.pl?cmd=showClients'
URL_PASSPORT = 'https://passport.yandex.ru/passport'

class DirectData(object):
	"""Get reports from Yandex Direct by Client-CampaignID tuples"""

	def __init__(self, login, password):
		self._login = login
		self._password = password
		self._session = Session()
		self._session.cookies = cookielib.CookieJar()
		self._auth()

	def _auth(self):
		params = {'mode': 'auth',
				  'retpath': URL_RET}
		data = {'login': self._login,
				'passwd': self._password,
				'retpath': URL_RET}
		response = self._session.post(URL_PASSPORT,
			params=params,
			data=data,
			allow_redirects=True)

	def _create_url_template(self,url):
		url = re.sub('main.*\.xls','main{0}.xls',re.sub('&cid=(\d)*.','&cid={0}&',re.sub('&ulogin=[a-z0-9-]*','&ulogin={1}',url)))
		return url

	def _get_report_content(self, url, client, campaignId):
		url = self._create_url_template(url)
		resp = self._session.get(url.format(campaignId,client))
		return resp.content

class FileWriter(object):
	"""Create folders and write xls-files with data"""
	def __init__(self, mainFolder):
		uniqueName = datetime.now().strftime("%y-%m-%d_%H-%M-%S_") + ''.join(random.SystemRandom().choice(string.ascii_uppercase + string.digits) for _ in range(5))
		if mainFolder[-1] != '\\':
			mainFolder += '\\'
		self._folderPath = mainFolder + uniqueName
		if not os.path.exists(self._folderPath):
			os.makedirs(self._folderPath)

	def _write_data_to_xls(self, data, campaignId):
		path = '{0}\\{1}.xls'.format(self._folderPath,campaignId)
		print path
		output = open(path, 'wb')
		output.write(data)
		output.close()

class PandasLayer(object):
	"""Read xls-files and concatenate in one file"""

	def __init__(self, folderPath):
		self._folderPath = folderPath
		self._dfs = []

	def _xls_to_df(self, client, campaignId):
		df = pd.read_excel('{0}\\{1}.xls'.format(self._folderPath,campaignId),skiprows=4,skip_footer=1)
		df[u'Кампания'] = campaignId
		df[u'Клиент'] = client
		self._dfs.append(df)

	def _concat_dfs_to_xls(self):
		uniqueName = datetime.now().strftime("%y-%m-%d_%H-%M-%S")
		total_df = pd.concat(self._dfs)
		total_df.to_excel('{0}\\{1}.xlsx'.format(self._folderPath,uniqueName), sheet_name='Data')

class DataTuples(object):
	"""Create and process Client-CampaignID tuples"""

	def __init__(self):
		self._tuples = []

	def _from_tab(self, n_separated_string):
		n_separated_data = n_separated_string.split('\n')
		for item in n_separated_data:
			tab_separated_data = item.split('\t')
			if len(tab_separated_data) != 2:
				continue
			self._tuples.append(tuple(tab_separated_data))

	def _from_list(self, list_of_tuples):
		self._tuples = list_of_tuples

def ProcessPairs(tuples,path,login,password,url):
	dd = DirectData(login,password)
	fw = FileWriter(path)
	pl = PandasLayer(fw._folderPath)
	for client, campaignId in tuples:
		xls_content = dd._get_report_content(url,client,campaignId)
		fw._write_data_to_xls(xls_content,campaignId)
		pl._xls_to_df(client,campaignId)
	pdf._concat_dfs_to_xls()

# %%
data = '''avtozap4asti-ru-cubo	16093119
avtozap4asti-ru-cubo	16093105
avtozap4asti-ru-cubo	16093132
avtozap4asti-ru-cubo	16093125
avtozap4asti-ru-cubo	16009440
avtozap4asti-ru-cubo	16054179
avtozap4asti-ru-cubo	16009033
avtozap4asti-ru-cubo	16054170
c123btru-cubo	15733858
c123btru-cubo	15746190
nlv-ru-cubo	16040429
cubo-esis-ru	15362845
cubo-esis-ru	15364498
cubo-esis-ru	15229063
cubo-esis-ru	15233763
pravo-ved-cubo	15904805
pravo-ved-cubo	15950729
'''
dt = DataTuples()
dt._from_tab(data)
path = 'D:\\direct_data\\'
login = 'Alexgrtula'
password = 'DhYwOHrW'
url = 'https://direct.yandex.ru/registered/04.01-11.01_main16009033.xls?filter_banner=&isStat=1&with_avg_position=1&m2=01&ulogin=avtozap4asti-ru-cubo&cmd=showCampStat&filter_gender=&stat_type=custom&filter_age=&d2=11&y1=16&filter_phrase=&filter_geo=&online_stat=1&filter_page_target=&goals=0&cid=16009033&filter_retargeting=&filter_page=&filter_tag=&offline_stat=0&with_auto_added_phrases=1&d1=04&filter_position=&group=day&group_by=tag%2C%20adgroup%2C%20banner%2C%20page%2C%20phrase%2C%20retargeting%2C%20geo%2C%20position%2C%20image%2C%20device_type%2C%20gender%2C%20age%2C%20date&y2=16&save_nds=1&filter_device_type=&filter_image=&stat_periods=2015-12-09%3A2016-01-03%2C2015-12-01%3A2016-01-11%2C2016-01-01%3A2016-01-11&with_nds=1&m1=01&filter_adgroup=&currency_archive=&onpage=100&xls=1'
ProcessTuples(dt._tuples,path,login,password,url)
# Out:
# Proccess campaign 16093119
