# %%
# -*- coding: utf-8 -*-
import allStuffHelper as ash
import pandas as pd

domain = 'doorlock.ru'
date1 = '2016-01-01'
date2 = '2016-09-11'

projectInfo = ash.getExtendedProjectInfo(domain,'Metrika')
goalsMetrics = ','.join(['ym:s:goal'+str(target['targetid'])+'visits' for target in ash.getCPATargetsByProjectID(projectInfo['projectid'])])
metrics = ','.join(['ym:s:visits',goalsMetrics])
dimensions='ym:s:dayOfWeek,ym:s:hour'
filters = "ym:s:UTMMedium=='direct'"
df = ash.getMetrikaReportInDataFrame(date1,date2,metrics,dimensions,projectInfo['token'],projectInfo['counterId'],filters,'lastsign')
df = ash.mergeCPAVisitsColumns(ash.dropTotalRow(df))
print 'Metrika Dataset Length:',len(df)
df.rename(columns={u'﻿"День недели визита"': 'dayofweek',
                        u'Час визита':'hour',
                        u'Визиты': 'visits'
                       }, inplace=True)
df.to_csv('data.csv',encoding='utf-8')
# Out:
# https://beta.api-metrika.yandex.ru/stat/v1/data.csv?dimensions=ym:s:dayOfWeek,ym:s:hour&metrics=ym:s:visits,ym:s:goal19189750visits,ym:s:goal2309269visits&date1=2016-01-01&date2=2016-09-11&ids=36936&oauth_token=AQAAAAABXbkcAAFxmMml_qhURE3lnu7wItxOUZ4&limit=100000&offset=1&filters=ym:s:UTMMedium=='direct'&accuracy=full&attribution=lastsign
# Metrika Dataset Length: 168

# %%
df
# Out:
#        dayofweek   hour  visits  goal_visits
# 0        Вторник  16:00     922          2.0
# 1        Пятница  11:00     917          3.0
# 2        Пятница  12:00     907          1.0
# 3          Среда  15:00     906          1.0
# 4    Понедельник  16:00     882          5.0
# 5    Воскресенье  20:00     870          0.0
# 6    Понедельник  19:00     868          1.0
# 7        Четверг  16:00     864          6.0
# 8    Понедельник  20:00     852          2.0
# 9          Среда  17:00     849          1.0
# 10   Понедельник  15:00     848          5.0
# 11   Понедельник  17:00     845          2.0
# 12         Среда  20:00     844          1.0
# 13       Вторник  11:00     840          2.0
# 14       Вторник  12:00     840          2.0
# 15         Среда  16:00     838          4.0
# 16       Вторник  17:00     834          8.0
# 17   Понедельник  14:00     822          2.0
# 18   Воскресенье  19:00     819          1.0
# 19       Четверг  15:00     812          1.0
# 20       Четверг  12:00     808          5.0
# 21   Воскресенье  18:00     807          2.0
# 22         Среда  14:00     804          0.0
# 23   Понедельник  13:00     798          3.0
# 24       Четверг  17:00     796          2.0
# 25       Вторник  21:00     792          2.0
# 26         Среда  21:00     788          0.0
# 27       Вторник  13:00     787          3.0
# 28       Вторник  15:00     787          2.0
# 29         Среда  10:00     781          6.0
# ..           ...    ...     ...          ...
# 138  Воскресенье  05:00     159          1.0
# 139        Среда  01:00     148          1.0
# 140      Пятница  05:00     147          1.0
# 141      Пятница  01:00     145          2.0
# 142  Понедельник  01:00     143          0.0
# 143  Воскресенье  01:00     133          0.0
# 144  Понедельник  04:00     127          0.0
# 145      Четверг  01:00     126          0.0
# 146      Вторник  01:00     120          0.0
# 147      Суббота  01:00     115          0.0
# 148      Вторник  04:00     106          0.0
# 149        Среда  04:00     106          0.0
# 150      Суббота  04:00      94          0.0
# 151      Пятница  04:00      85          0.0
# 152      Суббота  03:00      82          1.0
# 153  Воскресенье  02:00      82          0.0
# 154      Четверг  04:00      81          0.0
# 155  Воскресенье  04:00      77          0.0
# 156  Понедельник  02:00      74          0.0
# 157      Суббота  02:00      74          0.0
# 158        Среда  02:00      73          0.0
# 159      Вторник  03:00      66          0.0
# 160      Четверг  02:00      66          1.0
# 161      Вторник  02:00      63          0.0
# 162      Пятница  02:00      61          1.0
# 163  Воскресенье  03:00      58          0.0
# 164      Четверг  03:00      57          0.0
# 165      Пятница  03:00      57          0.0
# 166        Среда  03:00      54          0.0
# 167  Понедельник  03:00      50          0.0
#
# [168 rows x 4 columns]

# %%
import re
import json
data = []
with open('D:/123.txt','r') as f1:
    for row in f1:
        data.append(json.loads(re.findall('\{\"Sources.*',row)[0]))

# %%
df = pd.DataFrame(data)

# %%
df.to_csv('D:\\clickhs.csv')

# %%
df.columns
# Out:
# Index([u'Dimensions', u'Metrics', u'Segments', u'Sources', u'View'], dtype='object')
