# %%
import json
import logging
import sys
from googleads import adwords
from googleads import oauth2


logging.basicConfig(level=logging.INFO)
logging.getLogger('suds.transport').setLevel(logging.DEBUG)


# OAuth2 credential information. In a real application, you'd probably be
# pulling these values from a credential storage.
CLIENT_ID = '187376050914-b95hgu77nv4c1ld18gcj1e93nlfes82s.apps.googleusercontent.com'
CLIENT_SECRET = '4l07Oasm0snptfzRLbpw9Ihp'
REFRESH_TOKEN = '1/fON1tNVljx1X9YoOqlMUaFEfeDAAJwPqjdDgOZ8B_vpIgOrJDtdun6zK6XiATCKT'

# AdWords API information.
DEVELOPER_TOKEN = 'DBIbVe5MLt76TKcMgOjoiw'
USER_AGENT = 'test'
# CLIENT_CUSTOMER_ID = '6754700755' # main customer id, do not delete!!!
CLIENT_CUSTOMER_ID = '5643756059'

oauth2_client = oauth2.GoogleRefreshTokenClient(CLIENT_ID, CLIENT_SECRET, REFRESH_TOKEN)
adwords_client = adwords.AdWordsClient(DEVELOPER_TOKEN, oauth2_client, USER_AGENT, CLIENT_CUSTOMER_ID)
report_downloader = adwords_client.GetReportDownloader(version='v201603')

# return dictionary (domain) -> (customerId)
def get_client_map():
    # Initialize appropriate service.
    managed_customer_service = adwords_client.GetService('ManagedCustomerService', version='v201603')

    # Construct selector to get all accounts.
    selector = {
        'fields': ['CustomerId', 'Name'],
        'paging': {
            'startIndex': '0',
            'numberResults': '1000'
        }
    }
    accounts = {}

    # Get serviced account graph.
    page = managed_customer_service.get(selector)
    if 'entries' in page and page['entries']:
        # Map from customerID to account.
        for account in page['entries']:
            accounts[account['name']] = account['customerId']

    return accounts


# download report
def download_report(report, filename):
    # You can provide a file object to write the output to. For this demonstration
    # we use sys.stdout to write the report to the screen.
    body = report_downloader.DownloadReportAsString(report, skip_report_header=False, skip_column_header=False, skip_report_summary=False, include_zero_impressions=False)
    with open(filename, 'w') as text_file:
        text_file.write(body.encode('utf8'))




# Create report definition.
report = {
    'reportName': 'Last 7 days ADGROUP_PERFORMANCE_REPORT',
    'dateRangeType': 'LAST_7_DAYS',
    'reportType': 'ADGROUP_PERFORMANCE_REPORT',
    'downloadFormat': 'CSV',
    'selector': {
        'fields': ['CampaignId', 'AdNetworkType1', 'AdNetworkType2', 'Impressions', 'Clicks', 'Cost']
    }
}

#download_report(report, 'report.csv')
#print json.dumps(get_client_map())
# Out:
# DEBUG:suds.transport.http:opening (https://adwords.google.com/api/adwords/reportdownload/v201603/reportDefinition.xsd)
# send: 'GET /api/adwords/reportdownload/v201603/reportDefinition.xsd HTTP/1.1\r\nAccept-Encoding: identity\r\nHost: adwords.google.com\r\nConnection: close\r\nUser-Agent: Python-urllib/2.7\r\n\r\n'
# reply:
# DEBUG:suds.transport.http:opening (https://adwords.google.com/api/adwords/reportdownload/v201603/reportDefinition.xsd)
#  'HTTP/1.1 200 OK\r\n'
# header: Content-Type: text/xml; charset=UTF-8
# header: Date: Wed, 08 Jun 2016 13:12:03 GMT
# header: Expires: Wed, 08 Jun 2016 13:12:03 GMT
# header: Cache-Control: private, max-age=0
# header: X-Content-Type-Options: nosniff
# header: X-Frame-Options: SAMEORIGIN
# header: X-XSS-Protection: 1; mode=block
# header: Server: GSE
# header: Accept-Ranges: none
# header: Vary: Accept-Encoding
# header: Connection: close
# ...

# %% [markdown]
# hhghghg

# %%
client_ids = ['2139855129','1984230654','6032530740','5739854402','8668805171','2076754387','3520293416','9120857585','1397187279','1987048106','2374150753','3968130834','6032530740','1984230654','3968130834','1984230654','7677570104',
'1397187279','7111065283','6032530740','5597596239','8668805171','6409910634','5428441838','7502895477','5522204261','9062707193','2139855129','1984230654','6567634524','9524228173','9062707193','1984230654','7016173653',
'4273076484','2261855434','1584897268','9646978202','6795638214','1584897268','6032530740','9120857585','9385204305','3336156809','7751552289','1051228070','7111065283','3968130834','7751552289','1397187279','7016173653',
'3721988634','4273076484','2139855129','9646978202','5597596239','2244819587','5487273873','7755602718','6409910634','6147038989','9195656812','3897902909','5739854402','3520293416','7016173653','9195656812','4273076484',
'8205444083','7016173653','1987048106','9120857585','3520293416','5739854402','7016173653','1051228070','6147038989','3336156809','6147038989','7016173653','7751552289','5597596239','6371924683','5882881159','2527264383',
'3968130834','6147038989','5597596239','4273076484','2076754387','4948261250','7016173653','6029863865','3336156809','3520293416','6298370932']

# %%
report = {
    'reportName': 'Last 12 days ADGROUP_PERFORMANCE_REPORT',
    'dateRangeType': 'CUSTOM_DATE',
    'reportType': 'ADGROUP_PERFORMANCE_REPORT',
    'downloadFormat': 'CSV',
    'selector': {
        'fields': ['CampaignId', 'AdGroupId', 'AdGroupName', 'AdNetworkType1', 'Impressions', 'Clicks', 'Cost'],
        'dateRange': {'min':'20160526','max':'20160608'}
    }
}

for client_id in ['2139855129']:
    CLIENT_CUSTOMER_ID = client_id
    oauth2_client = oauth2.GoogleRefreshTokenClient(CLIENT_ID, CLIENT_SECRET, REFRESH_TOKEN)
    adwords_client = adwords.AdWordsClient(DEVELOPER_TOKEN, oauth2_client, USER_AGENT, CLIENT_CUSTOMER_ID)
    report_downloader = adwords_client.GetReportDownloader(version='v201603')
    download_report(report, u'D:\\_Docs_\\2016-06\\2016-05-26 Изменить ставки по SNDS и оценить изменение доли DS\\edemdom2.csv'.format(CLIENT_CUSTOMER_ID))
# Out:
# DEBUG:suds.transport.http:opening (https://adwords.google.com/api/adwords/reportdownload/v201603/reportDefinition.xsd)
# send: 'GET /api/adwords/reportdownload/v201603/reportDefinition.xsd HTTP/1.1\r\nAccept-Encoding: identity\r\nHost: adwords.google.com\r\nConnection: close\r\nUser-Agent: Python-urllib/2.7\r\n\r\n'
# reply:
# DEBUG:suds.transport.http:opening (https://adwords.google.com/api/adwords/reportdownload/v201603/reportDefinition.xsd)
#  'HTTP/1.1 200 OK\r\n'
# header: Content-Type: text/xml; charset=UTF-8
# header: Date: Wed, 08 Jun 2016 13:36:35 GMT
# header: Expires: Wed, 08 Jun 2016 13:36:35 GMT
# header: Cache-Control: private, max-age=0
# header: X-Content-Type-Options: nosniff
# header: X-Frame-Options: SAMEORIGIN
# header: X-XSS-Protection: 1; mode=block
# header: Server: GSE
# header: Accept-Ranges: none
# header: Vary: Accept-Encoding
# header: Connection: close
# ...

# %%
import pandas as pd

# %%
customerId = 1051228070
df = pd.read_csv('C:\\Users\\aleksey.makarov\\Desktop\\2016-05\\2016-05-24 Adwords SNDS Reports\\display\\{0}.csv'.format(customerId),skiprows=1,skipfooter=1)
# Out:
# C:\Users\aleksey.makarov\AppData\Local\Continuum\Anaconda\lib\site-packages\IPython\kernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   from IPython.kernel.zmq import kernelapp as app

# %%
df.rename(columns={'Impressions':'Display Impressions','Clicks':'Display Clicks','Cost':'Display Cost'},inplace=True)

# %%
df2 = pd.read_csv('C:\\Users\\aleksey.makarov\\Desktop\\2016-05\\2016-05-24 Adwords SNDS Reports\\keywords\\{0}.csv'.format(customerId),skiprows=1,skipfooter=1)
# Out:
# C:\Users\aleksey.makarov\AppData\Local\Continuum\Anaconda\lib\site-packages\IPython\kernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
merged_df_1 = pd.merge(df,df2,how='outer',on=['Campaign ID','Ad group ID','Keyword ID'])

# %%
df3 = pd.read_csv('C:\\Users\\aleksey.makarov\\Desktop\\2016-05\\2016-05-24 Adwords SNDS Reports\\adgroup\\{0}.csv'.format(customerId),skiprows=1,skipfooter=1)
# Out:
# C:\Users\aleksey.makarov\AppData\Local\Continuum\Anaconda\lib\site-packages\IPython\kernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
df3.rename(columns={'Impressions':'Ad group Impressions','Clicks':'Ad group Clicks','Cost':'Ad group Cost'},inplace=True)

# %%
merged_df_2 = pd.merge(merged_df_1,df3,how='left',on=['Campaign ID','Ad group ID'])

# %%
df4 = pd.read_csv('C:\\Users\\aleksey.makarov\\Desktop\\2016-05\\2016-05-24 Adwords SNDS Reports\\slots\\{0}.csv'.format(customerId),skiprows=1,skipfooter=1)
# Out:
# C:\Users\aleksey.makarov\AppData\Local\Continuum\Anaconda\lib\site-packages\IPython\kernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
df4['Top vs. Other'].unique()
# Out:
# array(['Google Display Network', 'Google search: Other',
#        'Google search: Top', 'Search partners: Top',
#        'Search partners: Other'], dtype=object)

# %%
import numpy as np
pivot = pd.pivot_table(df4, values=['Impressions','Clicks','Cost'], index=['Campaign ID', 'Ad group ID','Keyword ID','Keyword'],columns=['Top vs. Other'], aggfunc=np.sum,
              fill_value = 0)

# %%
pd.merge(merged_df_2,pivot,how='left',on=['Campaign ID','Ad group ID','Keyword ID'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-ed91d257abde> in <module>()
# ----> 1 pd.merge(merged_df_2,pivot,how='left',on=['Campaign ID','Ad group ID','Keyword ID'])
#
# C:\Users\aleksey.makarov\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\tools\merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      32                          right_on=right_on, left_index=left_index,
#      33                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 34                          copy=copy, indicator=indicator)
#      35     return op.get_result()
#      36 if __debug__:
#
# ...

# %%
pivot['Impressions']
# Out:
# Top vs. Other                                                                            Google Display Network  \
# Campaign ID Ad group ID Keyword ID   Keyword
# 461721662   23909948822 2073926882   expico                                                                   0
#             23909949302 166086207637 info-sert.ru                                                             0
#             23909950142 3000000      Content                                                                 94
#                         110283396328 альфа евро тест                                                          0
#             23909951582 62638168539  нефтегазбезопасность                                                     0
#             23909952662 166247067662 стандарт сертлит                                                         0
#             23909955662 166249107182 РусТехЭксперт                                                            0
# ...

# %%
pivot
# Out:
#                                                                                                    Impressions  \
# Top vs. Other                                                                           Google Display Network
# Campaign ID Ad group ID Keyword ID   Keyword
# 461721662   23909948822 2073926882   expico                                                                  0
#             23909949302 166086207637 info-sert.ru                                                            0
#             23909950142 3000000      Content                                                                94
#                         110283396328 альфа евро тест                                                         0
#             23909951582 62638168539  нефтегазбезопасность                                                    0
#             23909952662 166247067662 стандарт сертлит                                                        0
# ...

# %%
merged_df_2.to_csv('C:\\Users\\aleksey.makarov\\Desktop\\2016-05\\2016-05-24 Adwords SNDS Reports\\example.csv',decimal=',',sep=';')

# %%
df = pd.read_csv('C:\\Users\\aleksey.makarov\\Desktop\\2016-05\\2016-05-24 Adwords SNDS Reports\\display\\9195656812.csv'.format(customerId),skiprows=1,skipfooter=1)
# Out:
# C:\Users\aleksey.makarov\AppData\Local\Continuum\Anaconda\lib\site-packages\IPython\kernel\__main__.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skip_footer; you can avoid this warning by specifying engine='python'.
#   if __name__ == '__main__':

# %%
df[df['Campaign ID'] == 448259843].to_csv('D:\\kms_keywords_2.csv')

# %%
df
# Out:
#     Campaign ID  Ad group ID    Keyword ID  \
# 0     448259843  21646293923  147754694951
# 1     448259723  21646265123   24331882056
# 2     448259843  21646286603   63116200265
# 3     448259723  21646270643   70842805853
# 4     448259723  21646273283  147754694951
# 5     448259723  21646279283   60860712253
# 6     448259843  21646286003   27455789749
# 7     448259843  21646291283   70842805853
# 8     448259723  21646265363   27455789749
# 9     448259723  21646268003  147754693751
# 10    448259723  21646268123   60860714413
# 11    448259723  21646281443   27455798389
# 12    448259723  21646267883  147754693511
# 13    448259843  21646292243  147754670951
# 14    448259843  21646299923   60860712253
# 15    448259843  21646288643  147754693751
# 16    448259843  21646302083   27455798389
# 17    448259723  21646265603   35564828567
# 18    448259723  21646274123   63116204345
# 19    448259843  21646287323   60539613709
# 20    448259723  21646271243  147754675511
# ...
