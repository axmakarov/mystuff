# %%
url = "https://beta.api-metrika.yandex.ru/stat/v1/data.csv?dimensions=ym:s:<attribution>SearchPhrase&metrics=ym:s:visits,ym:s:bounceRate,ym:s:pageDepth,ym:s:avgVisitDurationSeconds&date1=2016-07-01&date2=2016-07-31&ids=34188145&oauth_token=AQAAAAAUYcmtAAFxmOUmbi2CFkBcrHha8QDwtBg&limit=20&offset=1&filters=ym:s:<attribution>TrafficSource=='organic' AND ym:s:regionCountry==%27225%27+and+ym:s:regionArea==%271%27&accuracy=full&attribution=lastsign"

import requests
import StringIO

output = StringIO.StringIO()
data = requests.get(url).text
print >>output, data
output.seek(0)
pd.read_csv(output,encoding='utf-8')
# Out:
#                                    ﻿"Поисковая фраза"  Визиты    Отказы  \
# 0                                     Итого и средние      81  0.123457
# 1         столовые приборы из нержавеющей стали gerus      35  0.085714
# 2                                       atlantic chif       7  0.000000
# 3                                 pinakotekaresto.com       7  0.142857
# 4                                          1201101007       3  0.666667
# 5                                        access чашка       2  0.000000
# 6                             www.pinakotekaresto.com       2  0.000000
# 7                        дренаж для гастроемкости 1/6       2  0.000000
# 8   1787050 емкости для джема и меда и нутеллы, gerus       1  0.000000
# 9                               1901000 стекло vitrum       1  0.000000
# 10                                     ermitage gerus       1  0.000000
# 11                                gerus ermitage цены       1  0.000000
# ...

# %%
contents = output.getvalue()

# %%
contents
# Out:
# '\xef\xbb\xbf"\xd0\x9f\xd0\xbe\xd0\xb8\xd1\x81\xd0\xba\xd0\xbe\xd0\xb2\xd0\xb0\xd1\x8f \xd1\x84\xd1\x80\xd0\xb0\xd0\xb7\xd0\xb0","\xd0\x92\xd0\xb8\xd0\xb7\xd0\xb8\xd1\x82\xd1\x8b","\xd0\x9e\xd1\x82\xd0\xba\xd0\xb0\xd0\xb7\xd1\x8b","\xd0\x93\xd0\xbb\xd1\x83\xd0\xb1\xd0\xb8\xd0\xbd\xd0\xb0 \xd0\xbf\xd1\x80\xd0\xbe\xd1\x81\xd0\xbc\xd0\xbe\xd1\x82\xd1\x80\xd0\xb0","\xd0\x92\xd1\x80\xd0\xb5\xd0\xbc\xd1\x8f \xd0\xbd\xd0\xb0 \xd1\x81\xd0\xb0\xd0\xb9\xd1\x82\xd0\xb5"\n"\xd0\x98\xd1\x82\xd0\xbe\xd0\xb3\xd0\xbe \xd0\xb8 \xd1\x81\xd1\x80\xd0\xb5\xd0\xb4\xd0\xbd\xd0\xb8\xd0\xb5","81","0.12345679012345678","7.987654320987654","00:10:21"\n"\xd1\x81\xd1\x82\xd0\xbe\xd0\xbb\xd0\xbe\xd0\xb2\xd1\x8b\xd0\xb5 \xd0\xbf\xd1\x80\xd0\xb8\xd0\xb1\xd0\xbe\xd1\x80\xd1\x8b \xd0\xb8\xd0\xb7 \xd0\xbd\xd0\xb5\xd1\x80\xd0\xb6\xd0\xb0\xd0\xb2\xd0\xb5\xd1\x8e\xd1\x89\xd0\xb5\xd0\xb9 \xd1\x81\xd1\x82\xd0\xb0\xd0\xbb\xd0\xb8 gerus","35","0.08571428571428572","14.342857142857143","00:18:40"\n"atlantic chif","7","0.0","4
# ...
