# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\aleksey.makarov\\Desktop\\2016-02\\Strategy_tree\\for_ml.txt',sep='\t',encoding='utf8',decimal=',')

# %% [markdown]
# Входные данные:

# %%
df.head(10)
# Out:
#               Домен            Канал  Сумма по полю Расход, руб  \
# 0          cesis.ru           AdLabs                       0.00
# 1          cesis.ru             Smi2                    6087.00
# 2          cesis.ru           Директ                   37535.75
# 3          cesis.ru  Директ (другое)                       0.00
# 4          cesis.ru    Директ(Поиск)                   37435.92
# 5          cesis.ru      Директ(РСЯ)                      99.83
# 6          cesis.ru      Доп. услуги                    1800.00
# 7          cesis.ru            Итого                   45422.75
# 8  pickup-center.ru          Adwords                   29537.85
# 9  pickup-center.ru              SEO                   10000.00
#
#    Сумма по полю Переходы  Сумма по полю Конверсии  \
# 0                       3                        0
# 1                    1626                        0
# 2                    1995                        0
# 3                     362                        0
# 4                     667                        0
# 5                      11                        0
# 6                       0                        0
# 7                    3624                        0
# 8                    7867                       13
# 9                       0                        0
#
#    Сумма по полю Кол-во звонков              Тематика Витрина товаров B2B/B2C  \
# 0                             1  Cистемы безопасности              Да     B2B
# 1                             0  Cистемы безопасности              Да     B2B
# 2                             1  Cистемы безопасности              Да     B2B
# 3                             0  Cистемы безопасности              Да     B2B
# 4                             0  Cистемы безопасности              Да     B2B
# 5                             0  Cистемы безопасности              Да     B2B
# 6                             0  Cистемы безопасности              Да     B2B
# 7                             2  Cистемы безопасности              Да     B2B
# 8                            20                  Авто              Да     B2C
# 9                             0                  Авто              Да     B2C
#
#   Опт/розница Товары / услуги Указаны ли на сайте цены Сформированность спроса
# 0           -   Товары&Услуги                      Нет                      Да
# 1           -   Товары&Услуги                      Нет                      Да
# 2           -   Товары&Услуги                      Нет                      Да
# 3           -   Товары&Услуги                      Нет                      Да
# 4           -   Товары&Услуги                      Нет                      Да
# 5           -   Товары&Услуги                      Нет                      Да
# 6           -   Товары&Услуги                      Нет                      Да
# 7           -   Товары&Услуги                      Нет                      Да
# 8           -   Товары&Услуги                       Да                      Да
# 9           -   Товары&Услуги                       Да                      Да

# %% [markdown]
# Группируем по каналу:

# %%
df2 = df.groupby([u'Канал'],as_index=False).sum()

# %%
df2
# Out:
#                      Канал  Сумма по полю Расход, руб  Сумма по полю Переходы  \
# 0                    AdHub                   27538.06                   59604
# 1                   AdLabs                 1553552.13                  462017
# 2                Adpremium                       0.00                    1825
# 3                  Adwords                 3272939.48                  322526
# 4                   AvitoC                   22077.68                   21719
# 5                      B2B                   10204.00                    1399
# 6                  Contema                       0.00                      79
# 7                   Cowboy                    3226.07                     673
# 8             DirectAdvert                       0.00                    1135
# 9                       FB                       0.00                      48
# 10  Google Merchant Center                       0.00                    5827
# 11                  Market                   12537.55                    3694
# 12             Mediatarget                       0.00                     104
# 13                PopUnder                       0.00                   23175
# 14                 RuClick                       0.00                       1
# 15                     SEO                 1537418.56                   37293
# 16                Smarttds                       0.00                    4659
# 17                    Smi2                 5109520.80                 1134335
# 18               SocialKey                   10084.69                    1244
# 19              TargetMail                  138472.17                    9572
# 20             Teasermedia                       0.00                     760
# 21              Traffik.ru                       0.00                     265
# 22                Traforet                       0.00                     505
# 23                      VK                   17446.66                    2097
# 24                 Баннеры                       0.00                    1188
# 25                  Директ                52805587.95                 1913044
# 26         Директ (другое)                       0.00                   89607
# 27           Директ(Поиск)                37575417.47                   92590
# 28             Директ(РСЯ)                14940101.37                   74651
# 29             Доп. услуги                  553489.62                       0
# 30                   Итого                65460207.65                 4071063
# 31               МаркетГид                  315832.22                   48875
# 32              Неизвестно                       0.00                    5412
# 33                Рассылка                   70280.00                    7988
#
#     Сумма по полю Конверсии  Сумма по полю Кол-во звонков
# 0                        20                             0
# 1                      1206                           226
# 2                         0                             0
# 3                      1059                           969
# 4                        14                             0
# 5                         8                             0
# 6                         0                             0
# 7                         0                             0
# 8                         0                             0
# 9                         0                             0
# 10                       31                             0
# 11                       35                             0
# 12                        0                             0
# 13                        1                             0
# 14                        0                             0
# 15                      194                           297
# 16                        0                             0
# 17                     2331                           541
# 18                        2                             0
# 19                       56                             3
# 20                        0                             0
# 21                        0                             0
# 22                        0                             0
# 23                        0                             3
# 24                        9                             0
# 25                    11072                          6241
# 26                      586                             0
# 27                      831                             0
# 28                      400                             0
# 29                        0                             0
# 30                    16111                          9247
# 31                       23                            14
# 32                       22                           953
# 33                       28                             0

# %% [markdown]
# Удаляем такие каналы, у которых нулевой расход или переходы

# %%
df2 = df2[(df2[u'Сумма по полю Расход, руб'] > 0) & (df2[u'Сумма по полю Переходы'] > 0)].reset_index(drop=True)

# %%
df2
# Out:
#             Канал  Сумма по полю Расход, руб  Сумма по полю Переходы  \
# 0           AdHub                   27538.06                   59604
# 1          AdLabs                 1553552.13                  462017
# 2         Adwords                 3272939.48                  322526
# 3          AvitoC                   22077.68                   21719
# 4             B2B                   10204.00                    1399
# 5          Cowboy                    3226.07                     673
# 6          Market                   12537.55                    3694
# 7             SEO                 1537418.56                   37293
# 8            Smi2                 5109520.80                 1134335
# 9       SocialKey                   10084.69                    1244
# 10     TargetMail                  138472.17                    9572
# 11             VK                   17446.66                    2097
# 12         Директ                52805587.95                 1913044
# 13  Директ(Поиск)                37575417.47                   92590
# 14    Директ(РСЯ)                14940101.37                   74651
# 15          Итого                65460207.65                 4071063
# 16      МаркетГид                  315832.22                   48875
# 17       Рассылка                   70280.00                    7988
#
#     Сумма по полю Конверсии  Сумма по полю Кол-во звонков
# 0                        20                             0
# 1                      1206                           226
# 2                      1059                           969
# 3                        14                             0
# 4                         8                             0
# 5                         0                             0
# 6                        35                             0
# 7                       194                           297
# 8                      2331                           541
# 9                         2                             0
# 10                       56                             3
# 11                        0                             3
# 12                    11072                          6241
# 13                      831                             0
# 14                      400                             0
# 15                    16111                          9247
# 16                       23                            14
# 17                       28                             0

# %% [markdown]
# Формируем список допустимых каналов, выбросив "Итого" и ошибочные каналы

# %%
channels = df2[~df2[u'Канал'].isin([u'Директ(Поиск)',u'Директ(РСЯ)',u'Итого'])][u'Канал'].reset_index(drop=True)

# %%
channels
# Out:
# 0          AdHub
# 1         AdLabs
# 2        Adwords
# 3         AvitoC
# 4            B2B
# 5         Cowboy
# 6         Market
# 7            SEO
# 8           Smi2
# 9      SocialKey
# 10    TargetMail
# 11            VK
# 12        Директ
# 13     МаркетГид
# 14      Рассылка
# Name: Канал, dtype: object

# %% [markdown]
# Формируем датафрейм с допустимыми каналами

# %%
df3 = df[df[u'Канал'].isin(channels)]

# %% [markdown]
# Проверяем, что суммарные данные по каналам сходятся

# %%
df3.groupby([u'Канал'],as_index=False).sum()
# Out:
#          Канал  Сумма по полю Расход, руб  Сумма по полю Переходы  \
# 0        AdHub                   27538.06                   59604
# 1       AdLabs                 1553552.13                  462017
# 2      Adwords                 3272939.48                  322526
# 3       AvitoC                   22077.68                   21719
# 4          B2B                   10204.00                    1399
# 5       Cowboy                    3226.07                     673
# 6       Market                   12537.55                    3694
# 7          SEO                 1537418.56                   37293
# 8         Smi2                 5109520.80                 1134335
# 9    SocialKey                   10084.69                    1244
# 10  TargetMail                  138472.17                    9572
# 11          VK                   17446.66                    2097
# 12      Директ                52805587.95                 1913044
# 13   МаркетГид                  315832.22                   48875
# 14    Рассылка                   70280.00                    7988
#
#     Сумма по полю Конверсии  Сумма по полю Кол-во звонков
# 0                        20                             0
# 1                      1206                           226
# 2                      1059                           969
# 3                        14                             0
# 4                         8                             0
# 5                         0                             0
# 6                        35                             0
# 7                       194                           297
# 8                      2331                           541
# 9                         2                             0
# 10                       56                             3
# 11                        0                             3
# 12                    11072                          6241
# 13                       23                            14
# 14                       28                             0

# %% [markdown]
# Удаляем строки данных без расхода или переходов

# %%
df4 = df3[(df3[u'Сумма по полю Расход, руб'] > 0) & (df3[u'Сумма по полю Переходы'] > 0)]

# %%
df4.groupby([u'Канал'],as_index=False).sum()
# Out:
#          Канал  Сумма по полю Расход, руб  Сумма по полю Переходы  \
# 0        AdHub                   27538.06                   53282
# 1       AdLabs                 1460394.21                  461857
# 2      Adwords                 3244554.47                  320588
# 3       AvitoC                   22077.68                   21712
# 4          B2B                    9464.00                     968
# 5       Cowboy                    2990.24                     460
# 6       Market                   10964.35                    3676
# 7          SEO                  508872.23                   37029
# 8         Smi2                 5102226.80                 1117514
# 9    SocialKey                    9904.00                     919
# 10  TargetMail                  129461.95                    8420
# 11          VK                   17446.66                    2073
# 12      Директ                49549103.73                 1909527
# 13   МаркетГид                  315681.29                   48863
# 14    Рассылка                   70280.00                    4187
#
#     Сумма по полю Конверсии  Сумма по полю Кол-во звонков
# 0                        20                             0
# 1                      1206                           205
# 2                      1059                           933
# 3                        14                             0
# 4                         6                             0
# 5                         0                             0
# 6                        35                             0
# 7                       191                           284
# 8                      2330                           516
# 9                         2                             0
# 10                       56                             3
# 11                        0                             3
# 12                    11072                          6241
# 13                       23                            14
# 14                       13                             0

# %% [markdown]
# Формируем датафрейм для обучения с нужными колонками

# %%
df5 = df4[[u'Канал',u'Сумма по полю Расход, руб',u'Сумма по полю Конверсии',u'Сумма по полю Переходы',u'Сумма по полю Кол-во звонков',u'Витрина товаров',u'Опт/розница',u'Товары / услуги',u'Указаны ли на сайте цены',u'Сформированность спроса',u'B2B/B2C']].reset_index(drop=True)

# %% [markdown]
# Переименовываем колонки

# %%
df5.rename(columns={u'Канал': 'channel',
                    u'B2B/B2C': 'b2b',
                    u'Сумма по полю Расход, руб': 'sum', 
                    u'Сумма по полю Переходы': 'clicks', 
                    u'Сумма по полю Конверсии': 'conversions', 
                    u'Сумма по полю Кол-во звонков': 'calls',
                    u'Витрина товаров': 'showcase',
                    u'Опт/розница': 'wholesale',
                    u'Товары / услуги': 'goods/services',
                    u'Указаны ли на сайте цены': 'isPrices',
                    u'Сформированность спроса': 'demand'
                   }, inplace=True)

# %%
df5.head(25)
# Out:
#        channel        sum  conversions  clicks  calls showcase    wholesale  \
# 0         Smi2    6087.00            0    1626      0       Да            -
# 1       Директ   37535.75            0    1995      1       Да            -
# 2      Adwords   29537.85           13    7867     20       Да            -
# 3         Smi2    4098.00            1    1050      0       Да            -
# 4       Директ   92585.45           15   29444     42       Да            -
# 5       Директ   14333.97            0    1020     27       Да  Опт&Розница
# 6         Smi2   34894.00            0    4719      0      Нет      Розница
# 7   TargetMail   11390.90            0     857      0      Нет      Розница
# 8           VK    1708.00            0     137      0      Нет      Розница
# 9    МаркетГид    7837.50            0    1077      0      Нет      Розница
# 10      AdLabs   62105.52            0   10928      2       Да  Опт&Розница
# 11      AvitoC     299.10            2     465      0       Да  Опт&Розница
# 12      Директ  623005.47           74   55302    182       Да  Опт&Розница
# 13     Adwords     307.93            0      30      0       Да  Опт&Розница
# 14        Smi2   10083.00            0    2808      0       Да  Опт&Розница
# 15      Директ   26638.12           10    5714      0       Да  Опт&Розница
# 16      Market      18.00            0      12      0       Да  Опт&Розница
# 17        Smi2     312.00            0      94      0       Да  Опт&Розница
# 18      Директ   99747.51          117   12643      0       Да  Опт&Розница
# 19      AdLabs    9383.48            2    4423      0      Нет            -
# 20     Adwords   25328.75            7    1307      0      Нет            -
# 21        Smi2    8140.50           13    1645      0      Нет            -
# 22      Директ   11193.70            3     317      0      Нет            -
# 23      AdLabs     217.83            0     106      2      Нет            -
# 24        Smi2     550.00            0      81      1      Нет            -
#
#    goods/services isPrices demand      b2b
# 0   Товары&Услуги      Нет     Да      B2B
# 1   Товары&Услуги      Нет     Да      B2B
# 2   Товары&Услуги       Да     Да      B2C
# 3   Товары&Услуги       Да     Да      B2C
# 4   Товары&Услуги       Да     Да      B2C
# 5   Товары&Услуги      Нет     Да      B2C
# 6   Товары&Услуги       Да     Да      B2C
# 7   Товары&Услуги       Да     Да      B2C
# 8   Товары&Услуги       Да     Да      B2C
# 9   Товары&Услуги       Да     Да      B2C
# 10         Товары       Да     Да  B2B&B2C
# 11         Товары       Да     Да  B2B&B2C
# 12         Товары       Да     Да  B2B&B2C
# 13         Товары       Да     Да  B2B&B2C
# 14         Товары       Да     Да  B2B&B2C
# 15         Товары       Да     Да  B2B&B2C
# 16         Товары       Да     Да  B2B&B2C
# 17         Товары       Да     Да  B2B&B2C
# 18         Товары       Да     Да  B2B&B2C
# 19         Услуги      Нет     Да      B2B
# 20         Услуги      Нет     Да      B2B
# 21         Услуги      Нет     Да      B2B
# 22         Услуги      Нет     Да      B2B
# 23         Услуги       Да     Да  B2B&B2C
# 24         Услуги       Да     Да  B2B&B2C

# %% [markdown]
# Формируем датафрейм с обучающими данными

# %%
train_df = df5[['channel','showcase','wholesale','goods/services','isPrices','demand','b2b']]

# %% [markdown]
# Из обучающего датафрейма делаем список словарей

# %%
list_of_dictionaries = [train_df.iloc[line,:].T.to_dict() for line in range(len(train_df))]

# %% [markdown]
# Делаем массив фич

# %%
from sklearn.feature_extraction import DictVectorizer
vec = DictVectorizer()

# %%
array = vec.fit_transform(list_of_dictionaries).toarray()

# %% [markdown]
# Получаем названия фич

# %%
vec.get_feature_names()
# Out:
# [u'b2b=B2B',
#  u'b2b=B2B&B2C',
#  u'b2b=B2C',
#  u'channel=AdHub',
#  u'channel=AdLabs',
#  u'channel=Adwords',
#  u'channel=AvitoC',
#  u'channel=B2B',
#  u'channel=Cowboy',
#  u'channel=Market',
#  u'channel=SEO',
#  u'channel=Smi2',
#  u'channel=SocialKey',
#  u'channel=TargetMail',
#  u'channel=VK',
#  u'channel=\u0414\u0438\u0440\u0435\u043a\u0442',
#  u'channel=\u041c\u0430\u0440\u043a\u0435\u0442\u0413\u0438\u0434',
#  u'channel=\u0420\u0430\u0441\u0441\u044b\u043b\u043a\u0430',
#  u'demand=\u0414\u0430',
#  u'demand=\u041d\u0435\u0442',
#  u'goods/services=\u0422\u043e\u0432\u0430\u0440\u044b',
#  u'goods/services=\u0422\u043e\u0432\u0430\u0440\u044b&\u0423\u0441\u043b\u0443\u0433\u0438',
#  u'goods/services=\u0423\u0441\u043b\u0443\u0433\u0438',
#  u'isPrices=\u0414\u0430',
#  u'isPrices=\u041d\u0435\u0442',
#  u'showcase=\u0414\u0430',
#  u'showcase=\u041d\u0435\u0442',
#  u'wholesale=-',
#  u'wholesale=\u041e\u043f\u0442',
#  u'wholesale=\u041e\u043f\u0442&\u0420\u043e\u0437\u043d\u0438\u0446\u0430',
#  u'wholesale=\u0420\u043e\u0437\u043d\u0438\u0446\u0430']

# %% [markdown]
# Создаем регрессоры

# %%
from sklearn import neighbors
knn_conversions = neighbors.KNeighborsRegressor(4)
knn_conversions.fit(array, df5['conversions'])
knn_sum = neighbors.KNeighborsRegressor(9)
knn_sum.fit(array, df5['sum'])
knn_clicks = neighbors.KNeighborsRegressor(10)
knn_clicks.fit(array, df5['clicks'])

from sklearn import linear_model
br_conversions = linear_model.BayesianRidge()
br_conversions.fit(array, df5['conversions'])
br_sum = linear_model.BayesianRidge()
br_sum.fit(array, df5['sum'])
br_clicks = linear_model.BayesianRidge()
br_clicks.fit(array, df5['clicks'])

from sklearn.ensemble import GradientBoostingRegressor
est_conversions = GradientBoostingRegressor(n_estimators=200, learning_rate=0.1, max_depth=1, random_state=0, loss='ls')
est_conversions.fit(array, df5['conversions'])
est_sum = GradientBoostingRegressor(n_estimators=200, learning_rate=0.1, max_depth=1, random_state=0, loss='ls')
est_sum.fit(array, df5['sum'])
est_clicks = GradientBoostingRegressor(n_estimators=200, learning_rate=0.1, max_depth=1, random_state=0, loss='ls')
est_clicks.fit(array, df5['clicks'])

from sklearn import tree
dtr_conversions = tree.DecisionTreeRegressor()
dtr_conversions.fit(array, df5['conversions'])
dtr_sum = tree.DecisionTreeRegressor()
dtr_sum.fit(array, df5['sum'])
dtr_clicks = tree.DecisionTreeRegressor()
dtr_clicks.fit(array, df5['clicks'])

from sklearn import linear_model
sgd_conversions = linear_model.SGDRegressor()
sgd_conversions.fit(array, df5['conversions'])
sgd_sum = linear_model.SGDRegressor()
sgd_sum.fit(array, df5['sum'])
sgd_clicks = linear_model.SGDRegressor()
sgd_clicks.fit(array, df5['clicks'])

from sklearn.svm import SVR
svr_conversions = SVR(C=1.0, epsilon=0.3)
svr_conversions.fit(array, df5['conversions'])
svr_sum = linear_model.SGDRegressor()
svr_sum.fit(array, df5['sum'])
svr_clicks = linear_model.SGDRegressor()
svr_clicks.fit(array, df5['clicks'])
# Out:
# SGDRegressor(alpha=0.0001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=5, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False)

# %% [markdown]
# Рассчитываем точность

# %%
print 'KNeighborsRegressor'
print 'Точность по конверсиям:', knn_conversions.score(array, df5['conversions'])
print 'Точность по расходу:', knn_sum.score(array, df5['sum'])
print 'Точность по кликам:', knn_clicks.score(array, df5['clicks'])
print ' '
print 'BayesianRidge'
print 'Точность по конверсиям:', br_conversions.score(array, df5['conversions'])
print 'Точность по расходу:', br_sum.score(array, df5['sum'])
print 'Точность по кликам:', br_clicks.score(array, df5['clicks'])
print ' '
print 'GradientBoostingRegressor'
print 'Точность по конверсиям:', est_conversions.score(array, df5['conversions'])
print 'Точность по расходу:', est_sum.score(array, df5['sum'])
print 'Точность по кликам:', est_clicks.score(array, df5['clicks'])
print ' '
print 'DecisionTreeRegressor'
print 'Точность по конверсиям:', dtr_conversions.score(array, df5['conversions'])
print 'Точность по расходу:', dtr_sum.score(array, df5['sum'])
print 'Точность по кликам:', dtr_clicks.score(array, df5['clicks'])
print ' '
print 'SGDRegressor'
print 'Точность по конверсиям:', sgd_conversions.score(array, df5['conversions'])
print 'Точность по расходу:', sgd_sum.score(array, df5['sum'])
print 'Точность по кликам:', sgd_clicks.score(array, df5['clicks'])
print ' '
print 'SVR'
print 'Точность по конверсиям:', svr_conversions.score(array, df5['conversions'])
print 'Точность по расходу:', svr_sum.score(array, df5['sum'])
print 'Точность по кликам:', svr_clicks.score(array, df5['clicks'])
# Out:
# KNeighborsRegressor
# Точность по конверсиям: 0.140442851257
# Точность по расходу: 0.138425880328
# Точность по кликам: 0.100813457404
#
# BayesianRidge
# Точность по конверсиям: 0.0505235017447
# Точность по расходу: 6.56314669278e-10
# Точность по кликам: 0.0846254753643
#
# GradientBoostingRegressor
# Точность по конверсиям: 0.0657575086487
# Точность по расходу: 0.0988214673765
# Точность по кликам: 0.0898775993892
#
# DecisionTreeRegressor
# Точность по конверсиям: 0.283031771426
# Точность по расходу: 0.183844055817
# Точность по кликам: 0.210365192353
#
# SGDRegressor
# Точность по конверсиям: 0.0434974354892
# Точность по расходу: 0.092793116278
# Точность по кликам: 0.0782880441644
#
# SVR
# Точность по конверсиям: -0.0238217259176
# Точность по расходу: 0.0921581646876
# Точность по кликам: 0.0772556644711

# %% [markdown]
# Прогоняем на тестовых данных

# %%
testData = {'channel': u'Директ',
           'b2b': u'B2B',
           'demand': u'Да',
           'goods/services': u'Товары',
           'isPrices': u'Да',
           'showcase': u'Да',
           'wholesale': u'Розница'}
point = vec.transform(testData).toarray()

print 'KNeighborsRegressor'
print 'Conversion:', knn_conversions.predict(point)[0]
print 'Sum:', knn_sum.predict(point)[0]
print 'Clicks:',knn_clicks.predict(point)[0]
print 'CPC:',knn_sum.predict(point)[0]/knn_clicks.predict(point)[0]
print 'Conversion:',knn_conversions.predict(point)[0]/knn_clicks.predict(point)[0]*100

print ' '
print 'DecisionTreeRegressor'
print 'Conversion:', dtr_conversions.predict(point)[0]
print 'Sum:', dtr_sum.predict(point)[0]
print 'Clicks:',dtr_clicks.predict(point)[0]
print 'CPC:',dtr_sum.predict(point)[0]/dtr_clicks.predict(point)[0]
print 'Conversion:',dtr_conversions.predict(point)[0]/dtr_clicks.predict(point)[0]*100

print ' '
print 'Сonfidence:',dtr_conversions.predict(point)[0]/dtr_clicks.predict(point)[0]*100-knn_conversions.predict(point)[0]/knn_clicks.predict(point)[0]*100
# Out:
# KNeighborsRegressor
# Conversion: 9.0
# Sum: 152255.278889
# Clicks: 4615.2
# CPC: 32.9899633578
# Conversion: 0.195007800312
#
# DecisionTreeRegressor
# Conversion: 9.0
# Sum: 55489.26
# Clicks: 5025.75
# CPC: 11.0409908969
# Conversion: 0.17907774959
#
# Сonfidence: -0.0159300507224

# %% [markdown]
# Получаем значения фич

# %%
for p in point:
    i = 0
    for j in p:
        print vec.get_feature_names()[i],j
        i += 1
# Out:
# b2b=B2B 1.0
# b2b=B2B&B2C 0.0
# b2b=B2C 0.0
# channel=AdHub 0.0
# channel=AdLabs 0.0
# channel=Adwords 0.0
# channel=AvitoC 0.0
# channel=B2B 0.0
# channel=Cowboy 0.0
# channel=Market 0.0
# channel=SEO 0.0
# channel=Smi2 1.0
# channel=SocialKey 0.0
# channel=TargetMail 0.0
# channel=VK 0.0
# channel=Директ 0.0
# channel=МаркетГид 0.0
# channel=Рассылка 0.0
# demand=Да 1.0
# demand=Нет 0.0
# goods/services=Товары 1.0
# goods/services=Товары&Услуги 0.0
# goods/services=Услуги 0.0
# isPrices=Да 1.0
# isPrices=Нет 0.0
# showcase=Да 1.0
# showcase=Нет 0.0
# wholesale=- 0.0
# wholesale=Опт 0.0
# wholesale=Опт&Розница 0.0
# wholesale=Розница 1.0

# %% [markdown]
# Получаем усредненные исходные данные

# %%
checkDataFrame = df5[(df5['channel'] == testData['channel']) &
   (df5['b2b'] == testData['b2b']) &
   (df5['demand'] == testData['demand']) &
   (df5['goods/services'] == testData['goods/services']) &
   (df5['isPrices'] == testData['isPrices']) &
   (df5['showcase'] == testData['showcase']) &
   (df5['wholesale'] == testData['wholesale'])].groupby([u'channel'],as_index=False).sum()
checkDataFrame['cr'] = checkDataFrame['conversions']/checkDataFrame['clicks']*100
checkDataFrame['cpc'] = checkDataFrame['sum']/checkDataFrame['clicks']
checkDataFrame
# Out:
# Empty DataFrame
# Columns: [channel, sum, conversions, clicks, calls, cr, cpc]
# Index: []

# %% [markdown]
# Рассчитываем статистику для всех вариантов

# %%
df5.columns
# Out:
# Index([u'channel', u'sum', u'conversions', u'clicks', u'calls', u'showcase',
#        u'wholesale', u'goods/services', u'isPrices', u'demand', u'b2b'],
#       dtype='object')

# %%
allStats = []
for channel in df5['channel'].unique().tolist():
    for b2b in df5['b2b'].unique().tolist():
        for goodsServices in df5['goods/services'].unique().tolist():
            for wholesale in df5['wholesale'].unique().tolist():
                for showcase in df5['showcase'].unique().tolist():
                    for wholesale in df5['wholesale'].unique().tolist():
                        for isPrices in df5['isPrices'].unique().tolist():
                            for demand in df5['demand'].unique().tolist():
                                testData = {'channel': channel,
           'b2b': b2b,
           'demand': demand,
           'goods/services': goodsServices,
           'isPrices': isPrices,
           'showcase': showcase,
           'wholesale': wholesale}
                                point = vec.transform(testData).toarray()
                                testData['knn_conversions'] = knn_conversions.predict(point)[0]
                                testData['knn_sum'] = knn_sum.predict(point)[0]
                                testData['knn_clicks'] = knn_clicks.predict(point)[0]
                                testData['knn_cpc'] = knn_sum.predict(point)[0]/knn_clicks.predict(point)[0]
                                testData['knn_cr'] = knn_conversions.predict(point)[0]/knn_clicks.predict(point)[0]*100
                                testData['dtr_conversions'] = dtr_conversions.predict(point)[0]
                                testData['dtr_sum'] = dtr_sum.predict(point)[0]
                                testData['dtr_clicks'] = dtr_clicks.predict(point)[0]
                                testData['dtr_cpc'] = dtr_sum.predict(point)[0]/knn_clicks.predict(point)[0]
                                testData['dtr_cr'] = dtr_conversions.predict(point)[0]/knn_clicks.predict(point)[0]*100
                                testData['confidence'] = testData['dtr_conversions'] - testData['knn_conversions']
                                allStats.append(testData)

# %%
pd.DataFrame(allStats).to_excel('D:\\strategy_tree_calc.xlsx')
