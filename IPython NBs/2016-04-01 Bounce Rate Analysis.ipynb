# %%
import json
import requests
import pandas as pd
from datetime import datetime,timedelta, date
from operator import itemgetter

def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)
        
def createOlapPayload(sources,metrics,dimensions,startDate,endDate,filters):
	data = {}
	data['sources'] = sources
	data['metrics'] = metrics
	i = 1
	dimensionsDict = {}
	for dimension in dimensions:
		dimensionsDict[dimension] = i
		i += 1
	data['dimensions'] = dimensionsDict
	date1 = datetime.strptime(startDate,'%Y-%m-%d').strftime("%Y-%m-%d")
	date2 = (datetime.strptime(endDate,'%Y-%m-%d') + timedelta(1)).strftime("%Y-%m-%d")
	segments = []
	segmentsDict = {}
	segmentsDict['dateStart'] = "{0}T00:00:00+03:00".format(date1)
	segmentsDict['dateEnd'] = "{0}T00:00:00+03:00".format(date2)
	segmentsDict['filters'] = {}
	for filterKey, filterValue in filters.iteritems():
		segmentsDict['filters'][filterKey] = {}
		segmentsDict['filters'][filterKey]['type'] = 'DIMENSION'
		segmentsDict['filters'][filterKey]['ids'] = filterValue
	segments.append(segmentsDict)
	data['segments'] = segments
	return data

def getJSONOlapResponse(data):
	url = 'http://192.168.10.5:4000/api/OLAP/Plain'
	headers = {'Content-Type': 'application/json'}
	response = requests.post(url,data,headers=headers)
	return json.loads(response.text)

def transformOlapResponse(response,payload):
	data = []
	dimensionsList = [{'key': k, 'value': v} for k,v in payload['dimensions'].iteritems()]
	dimensionsList = sorted(dimensionsList, key=itemgetter('value'))
	for item in response:
		i = 0
		dataDict = {}
		for dimensionValue in item['dimensions']:
			dimensionName = dimensionsList[i]['key']
			dataDict[dimensionName] = dimensionValue
			i += 1
		metrics = item['value'][0]
		for k,v in metrics.iteritems():
			dataDict[k] = v
		data.append(dataDict)
	return data

# %%
start_date = date(2016, 3, 1)
end_date = date(2016, 3, 2)

# %%
total_df = pd.DataFrame()
for date1 in daterange(start_date, end_date):
    print date1,
    date2 = date1 + timedelta(1)
    print '\t',date2
    filters = {'campaignTypeId': ['1','2'], 'projectId': ['2337938','2425053','2376103','2404711','2406006','2273493','2345116','2371741','2214297','2337395','2434227','2357499']}
    source = ["direct_bid","direct_conversion","metrika"]
    metrics = ["shows","clicks","spent","visits","cpaVisits","rejectPercent"]
    dimensions = ['dateDay','campaignExternalId','campaignName','adExternalId','keyPhraseName']
    startDate = date1.strftime("%Y-%m-%d")
    endDate = date2.strftime("%Y-%m-%d")
    payload = createOlapPayload(source,metrics,dimensions,startDate,endDate,filters)
    response = getJSONOlapResponse(json.dumps(payload))
    print 'Get Response'
    data = transformOlapResponse(response,payload)
    df = pd.DataFrame(data)
    total_df = pd.concat([total_df,df])
# Out:
# 2016-03-01 	2016-03-02
# Get Response
# 2016-03-02 	2016-03-03
# Get Response
# 2016-03-03 	2016-03-04
# Get Response
# 2016-03-04 	2016-03-05
# Get Response
# 2016-03-05 	2016-03-06
# Get Response
# 2016-03-06 	2016-03-07
# Get Response
# 2016-03-07 	2016-03-08
# Get Response
# 2016-03-08 	2016-03-09
# Get Response
# 2016-03-09 	2016-03-10
# Get Response
# 2016-03-10 	2016-03-11
# Get Response
# 2016-03-11 	2016-03-12
# Get Response
# 2016-03-12 	2016-03-13
# Get Response
# 2016-03-13 	2016-03-14
# Get Response
# 2016-03-14 	2016-03-15
# Get Response
# 2016-03-15 	2016-03-16
# Get Response
# 2016-03-16 	2016-03-17
# Get Response
# 2016-03-17 	2016-03-18
# Get Response
# 2016-03-18 	2016-03-19
# Get Response
# 2016-03-19 	2016-03-20
# Get Response
# 2016-03-20 	2016-03-21
# Get Response
# 2016-03-21 	2016-03-22
# Get Response
# 2016-03-22 	2016-03-23
# Get Response
# 2016-03-23 	2016-03-24
# Get Response
# 2016-03-24 	2016-03-25
# Get Response
# 2016-03-25 	2016-03-26
# Get Response
# 2016-03-26 	2016-03-27
# Get Response
# 2016-03-27 	2016-03-28
# Get Response
# 2016-03-28 	2016-03-29
# Get Response
# 2016-03-29 	2016-03-30
# Get Response

# %%
total_df
# Out:
#        adExternalId campaignExternalId                           campaignName  \
# 0         564665598           10489147                      SAAB автозапчасти
# 1         564665598           10489147                      SAAB автозапчасти
# 2         564665598           10489147                      SAAB автозапчасти
# 3         564665598           10489147                      SAAB автозапчасти
# 4         564665598           10489147                      SAAB автозапчасти
# 5         564665598           10489147                      SAAB автозапчасти
# 6         564665598           10489147                      SAAB автозапчасти
# 7         564665598           10489147                      SAAB автозапчасти
# 8         564665598           10489147                      SAAB автозапчасти
# 9         564665598           10489147                      SAAB автозапчасти
# 10        564665598           10489147                      SAAB автозапчасти
# 11        564665598           10489147                      SAAB автозапчасти
# 12        564665598           10489147                      SAAB автозапчасти
# 13        564665598           10489147                      SAAB автозапчасти
# 14        564665598           10489147                      SAAB автозапчасти
# 15        564665598           10489147                      SAAB автозапчасти
# 16        564665598           10489147                      SAAB автозапчасти
# 17        564665598           10489147                      SAAB автозапчасти
# 18        564665598           10489147                      SAAB автозапчасти
# 19        564665598           10489147                      SAAB автозапчасти
# 20        564665598           10489147                      SAAB автозапчасти
# 21        564665598           10489147                      SAAB автозапчасти
# 22        564665598           10489147                      SAAB автозапчасти
# 23        564665598           10489147                      SAAB автозапчасти
# 24        564665598           10489147                      SAAB автозапчасти
# 25        564665598           10489147                      SAAB автозапчасти
# 26        564665598           10489147                      SAAB автозапчасти
# 27        564665598           10489147                      SAAB автозапчасти
# 28        564665598           10489147                      SAAB автозапчасти
# 29        564665598           10489147                      SAAB автозапчасти
# ...             ...                ...                                    ...
# 122670   1929696637           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122671   1929696637           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122672   1929696638           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122673   1929696638           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122674   1929696638           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122675   1929696638           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122676   1929696639           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122677   1929696639           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122678   1929696639           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122679   1929696639           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122680   1929696640           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122681   1929696640           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122682   1929696640           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122683   1929696640           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122684   1929696641           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122685   1929696641           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122686   1929696641           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122687   1929696641           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122688   1929696642           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122689   1929696642           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122690   1929696642           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122691   1929696642           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122692   1929696643           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122693   1929696643           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122694   1929696643           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122695   1929696643           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122696   1929696644           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122697   1929696644           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122698   1929696644           17666923  okna-okoshkino Поиск Волгодонск на РФ
# 122699   1929696644           17666923  okna-okoshkino Поиск Волгодонск на РФ
#
#         clicks  cpaVisits     dateDay  goalVisits  \
# 0            0          0  2016-03-01           0
# 1            0          0  2016-03-01           0
# 2            0          0  2016-03-01           0
# 3            0          0  2016-03-01           0
# 4            0          0  2016-03-01           0
# 5            0          0  2016-03-01           0
# 6            0          0  2016-03-01           0
# 7            0          0  2016-03-01           0
# 8            0          0  2016-03-01           0
# 9            0          0  2016-03-01           0
# 10           0          0  2016-03-01           0
# 11           0          0  2016-03-01           0
# 12           0          0  2016-03-01           0
# 13           0          0  2016-03-01           0
# 14           0          0  2016-03-01           0
# 15           0          0  2016-03-01           0
# 16           0          0  2016-03-01           0
# 17           0          0  2016-03-01           0
# 18           0          0  2016-03-01           0
# 19           0          0  2016-03-01           0
# 20           0          0  2016-03-01           0
# 21           0          0  2016-03-01           0
# 22           0          0  2016-03-01           0
# 23           0          0  2016-03-01           0
# 24           0          0  2016-03-01           0
# 25           0          0  2016-03-01           0
# 26           0          0  2016-03-01           0
# 27           0          0  2016-03-01           0
# 28           0          0  2016-03-01           0
# 29           0          0  2016-03-01           0
# ...        ...        ...         ...         ...
# 122670       0          0  2016-03-30           0
# 122671       0          0  2016-03-30           0
# 122672       0          0  2016-03-30           0
# 122673       0          0  2016-03-30           0
# 122674       0          0  2016-03-30           0
# 122675       0          0  2016-03-30           0
# 122676       0          0  2016-03-30           0
# 122677       0          0  2016-03-30           0
# 122678       0          0  2016-03-30           0
# 122679       0          0  2016-03-30           0
# 122680       0          0  2016-03-30           0
# 122681       0          0  2016-03-30           0
# 122682       0          0  2016-03-30           0
# 122683       0          0  2016-03-30           0
# 122684       0          0  2016-03-30           0
# 122685       0          0  2016-03-30           0
# 122686       0          0  2016-03-30           0
# 122687       0          0  2016-03-30           0
# 122688       0          0  2016-03-30           0
# 122689       0          0  2016-03-30           0
# 122690       0          0  2016-03-30           0
# 122691       0          0  2016-03-30           0
# 122692       0          0  2016-03-30           0
# 122693       0          0  2016-03-30           0
# 122694       0          0  2016-03-30           0
# 122695       0          0  2016-03-30           0
# 122696       0          0  2016-03-30           0
# 122697       0          0  2016-03-30           0
# 122698       0          0  2016-03-30           0
# 122699       0          0  2016-03-30           0
#
#                                             keyPhraseName  rejectPercent  \
# 0                                       Saab 900 запчасти              0
# 1                                 Saab 9000 запчасти цены              0
# 2                                      Saab 9000 разборка              0
# 3                                     Авито запчасти Сааб              0
# 4                                       Автозапчасти CААБ              0
# 5                                  Автозапчасти Saab Б +У              0
# 6                                    Автозапчасти Saab БУ              0
# 7                                Автозапчасти Saab дешево              0
# 8                                Автозапчасти Saab купить              0
# 9                              Автозапчасти Saab недорого              0
# 10                                 Автозапчасти Saab цена              0
# 11                                 Автозапчасти Сааб Б +У              0
# 12                                   Автозапчасти Сааб БУ              0
# 13                               Автозапчасти Сааб дешево              0
# 14                               Автозапчасти Сааб купить              0
# 15                             Автозапчасти Сааб недорого              0
# 16                                 Автозапчасти Сааб цена              0
# 17                                  Автозапчасти для Saab              0
# 18                             Б +у запчасти +на Сааб 9 3              0
# 19                                 Б +у запчасти Saab 9 5              0
# 20                                Бу запчасти +на Сааб 95              0
# 21                                       Бу запчасти Saab              0
# 22                                   Бу запчасти Сааб 9 5              0
# 23                                            Детали Saab              0
# 24                                 Запчасти +на Saab 9000              0
# 25                                   Запчасти +на Saab 93              0
# 26                                  Запчасти +на Сааб 9 3              0
# 27                             Запчасти +на Сааб 9 3 цена              0
# 28                                  Запчасти +на Сааб 9 5              0
# 29                                 Запчасти +на Сааб 9000              0
# ...                                                   ...            ...
# 122670             "Окошкино официальный сайт Волгодонск"              0
# 122671               Окошкино официальный сайт Волгодонск              0
# 122672      !Заказать !пластиковые !окна !veka Волгодонск              0
# 122673    "!Заказать !пластиковые !окна !veka Волгодонск"              0
# 122674        "Заказать пластиковые окна veka Волгодонск"              0
# 122675          Заказать пластиковые окна veka Волгодонск              0
# 122676        !Окошкино !официальный !сайт +в Волгодонске              0
# 122677       "!Окошкино !официальный !сайт в Волгодонске"              0
# 122678          "Окошкино официальный сайт в Волгодонске"              0
# 122679           Окошкино официальный сайт +в Волгодонске              0
# 122680                               !Окошкино Волгодонск              0
# 122681                             "!Окошкино Волгодонск"              0
# 122682                              "Окошкино Волгодонск"              0
# 122683                                Окошкино Волгодонск              0
# 122684  !Заказать !пластиковые !окна !века +в Волгодонске              0
# 122685  "!Заказать !пластиковые !окна !века в Волгодон...              0
# 122686     "Заказать пластиковые окна века в Волгодонске"              0
# 122687      Заказать пластиковые окна века +в Волгодонске              0
# 122688                           !Окошкино +в Волгодонске              0
# 122689                          "!Окошкино в Волгодонске"              0
# 122690                           "Окошкино в Волгодонске"              0
# 122691                            Окошкино +в Волгодонске              0
# 122692                          !Профиль !veka Волгодонск              0
# 122693                        "!Профиль !veka Волгодонск"              0
# 122694                          "Профиль veka Волгодонск"              0
# 122695                            Профиль veka Волгодонск              0
# 122696                      !Профиль !века +в Волгодонске              0
# 122697                     "!Профиль !века в Волгодонске"              0
# 122698                       "Профиль века в Волгодонске"              0
# 122699                        Профиль века +в Волгодонске              0
#
#         shows  spent  visits
# 0           0      0       0
# 1           0      0       0
# 2           0      0       0
# 3           0      0       0
# 4           0      0       0
# 5           0      0       0
# 6           0      0       0
# 7           0      0       0
# 8           0      0       0
# 9           0      0       0
# 10          0      0       0
# 11          0      0       0
# 12          0      0       0
# 13          0      0       0
# 14          0      0       0
# 15          0      0       0
# 16          0      0       0
# 17          0      0       0
# 18          0      0       0
# 19          0      0       0
# 20          0      0       0
# 21          0      0       0
# 22          0      0       0
# 23          0      0       0
# 24          0      0       0
# 25          0      0       0
# 26          0      0       0
# 27          0      0       0
# 28          0      0       0
# 29          0      0       0
# ...       ...    ...     ...
# 122670      0      0       0
# 122671      0      0       0
# 122672      0      0       0
# 122673      0      0       0
# 122674      0      0       0
# 122675      0      0       0
# 122676      0      0       0
# 122677      0      0       0
# 122678      0      0       0
# 122679      0      0       0
# 122680      0      0       0
# 122681      1      0       0
# 122682      1      0       0
# 122683      3      0       0
# 122684      0      0       0
# 122685      0      0       0
# 122686      0      0       0
# 122687      0      0       0
# 122688      0      0       0
# 122689      0      0       0
# 122690      0      0       0
# 122691      0      0       0
# 122692      0      0       0
# 122693      0      0       0
# 122694      0      0       0
# 122695      0      0       0
# 122696      0      0       0
# 122697      0      0       0
# 122698      0      0       0
# 122699      0      0       0
#
# [3074745 rows x 12 columns]

# %%
from pandas import HDFStore
store = HDFStore('D:\\store2.h5')

# %%
store['total_df'] = total_df
# Out:
# C:\Users\aleksey.makarov\AppData\Local\Continuum\Anaconda\lib\site-packages\IPython\kernel\__main__.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->axis0] [items->None]
#
#   if __name__ == '__main__':
# C:\Users\aleksey.makarov\AppData\Local\Continuum\Anaconda\lib\site-packages\IPython\kernel\__main__.py:1: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->unicode,key->block0_items] [items->None]
#
#   if __name__ == '__main__':

# %%
total_df.to_csv('D:\\bounce_rate.csv',encoding='utf-8',sep='\t')

# %%
store.close()

# %%
store = HDFStore('D:\\store.h5')

# %%
store.close()

# %%
total_df['bounces'] = total_df['visits']*total_df['rejectPercent']/100

# %%
total_df.columns
# Out:
# Index([      u'adExternalId', u'campaignExternalId',       u'campaignName',
#                    u'clicks',          u'cpaVisits',            u'dateDay',
#                u'goalVisits',      u'keyPhraseName',      u'rejectPercent',
#                     u'shows',              u'spent',             u'visits',
#                   u'bounces'],
#       dtype='object')

# %%
grouped_df = total_df.groupby(['adExternalId','campaignExternalId','keyPhraseName','campaignName'],as_index=False).sum()

# %%
grouped_df = grouped_df[grouped_df['shows'] > 0]

# %%
grouped_df['bounce_rate'] = grouped_df['bounces']/grouped_df['visits']

# %%
grouped_df[(grouped_df['bounce_rate'] == 0.0)]['cpaVisits'].sum()/grouped_df[(grouped_df['bounce_rate'] == 0.0)]['visits'].sum()*100
# Out:
# 1.1429642121041785

# %%
grouped_df_drop_na = grouped_df.dropna()

# %%
campaigns_df = grouped_df_drop_na[['campaignExternalId','visits','bounces']].groupby(['campaignExternalId'],as_index=False).sum()

# %%
campaigns_df['campaign_bounce_rate'] = campaigns_df['bounces']/campaigns_df['visits']

# %%
merged_df = pd.merge(grouped_df_drop_na,campaigns_df[['campaignExternalId','campaign_bounce_rate']],how='left',on=['campaignExternalId'])

# %%
ads_df = grouped_df_drop_na[['adExternalId','visits','bounces']].groupby(['adExternalId'],as_index=False).sum()

# %%
ads_df['ad_bounce_rate'] = ads_df['bounces']/ads_df['visits']

# %%
merged_df = pd.merge(merged_df,ads_df[['adExternalId','ad_bounce_rate']],how='left',on=['adExternalId'])

# %%
merged_df.to_excel('D:\\bounce_rate_analysis2.xlsx')

# %%
campaigns_ads = pd.read_csv(u'C:\\Users\\aleksey.makarov\\Desktop\\2016-04\\Анализ показателя отказов\\campaign_ads_keys.csv')

# %%
test_df = campaigns_ads.groupby(['adGroupId','campaignId'],as_index = False).count()

# %%
test_df[test_df['externalId'] > 3].groupby(['campaignId'],as_index=False).count().sort_values(by='adGroupId',ascending =False).to_clipboard()

# %%
len(merged_df['campaignExternalId'].unique())
# Out:
# 117

# %%
len(merged_df['adExternalId'].unique())
# Out:
# 2657

# %%
len(merged_df['keyPhraseName'])
# Out:
# 4922
